# %% [markdown]
# <a href="https://colab.research.google.com/github/bouracha/CatanAI/blob/master/pix2pix.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Colaboratory Notebooks for pix2pix
#
# ![Teaser](https://i.imgur.com/D3GpTZul.jpg)
#
# This is a collection of Colaboratory notebooks for training [pix2pix](https://phillipi.github.io/pix2pix/) (image-to-image translation) model.
#
# - [Image segmentation and preprocessing](https://colab.research.google.com/drive/1hk1TaF8DmTcJ6S6Cg8q6wRqoWkP4_9K-)
# - [Edge detection with HED (holistically-nested edge detection)](https://colab.research.google.com/drive/1SI57hLgHCX6mbZ2jNveNvq1Pqx07Jag7)
# - [Combining input/target image pair](https://colab.research.google.com/drive/161Eohk6bhij02KjrakgnDy_vTuSNeheo)
# - [Training pix2pix network](https://colab.research.google.com/drive/182CGDnFxt08NmjCCTu5jDweUjn3jhB2y)
# - [Weight data exporter](https://colab.research.google.com/drive/1Dc3E6GJ4jjlBIJLaJd--FgKFQGpa_O5N)
#
# ## Acknowledgements
#
# pix2pix was originally developed by [Isola et al.](https://phillipi.github.io/pix2pix/) using Torch, then ported to TensorFlow by [affinelayer](https://github.com/affinelayer/pix2pix-tensorflow). The Colaboratory Notebook was written by [Zaid Alyafeai](https://github.com/zaidalyafeai/zaidalyafeai.github.io). I (keijiro) added some preprocessing scripts.

# %% [markdown]
# ## Need to be using tensorflow 1.x

# %%
# %tensorflow_version 1.x
# Out:
# TensorFlow 1.x selected.

# %%
import tensorflow as tf
print(tf.__version__)
# Out:
# 1.15.2

# %% [markdown]
# ## Check HPC libraries

# %%
# !nvidia-smi
# Out:
# Wed Apr  8 23:35:25 2020
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 440.64.00    Driver Version: 418.67       CUDA Version: 10.1     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   36C    P0    27W / 250W |      0MiB / 16280MiB |      0%      Default |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                       GPU Memory |
# |  GPU       PID   Type   Process name                             Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
# !nvcc --version
# Out:
# nvcc: NVIDIA (R) Cuda compiler driver
# Copyright (c) 2005-2019 NVIDIA Corporation
# Built on Sun_Jul_28_19:07:16_PDT_2019
# Cuda compilation tools, release 10.1, V10.1.243

# %%
import tensorflow as tf
tf.test.gpu_device_name()
# Out:
# '/device:GPU:0'

# %% [markdown]
# ## Clone repository, change to appropriate directory and test on facades dataset

# %%
# clone this repo
# !git clone https://github.com/affinelayer/pix2pix-tensorflow.git
# Out:
# Cloning into 'pix2pix-tensorflow'...
# remote: Enumerating objects: 261, done.
# remote: Total 261 (delta 0), reused 0 (delta 0), pack-reused 261
# Receiving objects: 100% (261/261), 13.33 MiB | 16.61 MiB/s, done.
# Resolving deltas: 100% (103/103), done.

# %%
import os
os.chdir("pix2pix-tensorflow")

# %%
#!cd pix2pix-tensorflow
# download the CMP Facades dataset (generated from http://cmp.felk.cvut.cz/~tylecr1/facade/)
# !python tools/download-dataset.py facades
# Out:
# downloading https://people.eecs.berkeley.edu/~tinghuiz/projects/pix2pix/datasets/facades.tar.gz
# extracting
# done

# %%
# !python pix2pix.py \
  --mode train \
  --output_dir facades_train \
  --max_epochs 200 \
  --input_dir facades/test \
  --which_direction BtoA
# Out:
# WARNING:tensorflow:From pix2pix.py:540: The name tf.set_random_seed is deprecated. Please use tf.compat.v1.set_random_seed instead.
#
# aspect_ratio = 1.0
# batch_size = 1
# beta1 = 0.5
# checkpoint = None
# display_freq = 0
# flip = True
# gan_weight = 1.0
# input_dir = facades/test
# l1_weight = 100.0
# lab_colorization = False
# lr = 0.0002
# max_epochs = 200
# max_steps = None
# mode = train
# ndf = 64
# ngf = 64
# output_dir = facades_train
# output_filetype = png
# progress_freq = 50
# save_freq = 5000
# scale_size = 286
# seed = 29428488
# separable_conv = False
# summary_freq = 100
# trace_freq = 0
# which_direction = BtoA
# WARNING:tensorflow:From pix2pix.py:258: string_input_producer (from tensorflow.python.training.input) is deprecated and will be removed in a future version.
# Instructions for updating:
# Queue-based input pipelines have been replaced by `tf.data`. Use `tf.data.Dataset.from_tensor_slices(string_tensor).shuffle(tf.shape(input_tensor, out_type=tf.int64)[0]).repeat(num_epochs)`. If `shuffle=False`, omit the `.shuffle(...)`.
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.6/tensorflow_core/python/training/input.py:277: input_producer (from tensorflow.python.training.input) is deprecated and will be removed in a future version.
# Instructions for updating:
# Queue-based input pipelines have been replaced by `tf.data`. Use `tf.data.Dataset.from_tensor_slices(input_tensor).shuffle(tf.shape(input_tensor, out_type=tf.int64)[0]).repeat(num_epochs)`. If `shuffle=False`, omit the `.shuffle(...)`.
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.6/tensorflow_core/python/training/input.py:189: limit_epochs (from tensorflow.python.training.input) is deprecated and will be removed in a future version.
# Instructions for updating:
# Queue-based input pipelines have been replaced by `tf.data`. Use `tf.data.Dataset.from_tensors(tensor).repeat(num_epochs)`.
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.6/tensorflow_core/python/training/input.py:198: QueueRunner.__init__ (from tensorflow.python.training.queue_runner_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# To construct input pipelines, use the `tf.data` module.
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.6/tensorflow_core/python/training/input.py:198: add_queue_runner (from tensorflow.python.training.queue_runner_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# To construct input pipelines, use the `tf.data` module.
# WARNING:tensorflow:From pix2pix.py:259: WholeFileReader.__init__ (from tensorflow.python.ops.io_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Queue-based input pipelines have been replaced by `tf.data`. Use `tf.data.Dataset.map(tf.read_file)`.
# WARNING:tensorflow:From pix2pix.py:264: The name tf.assert_equal is deprecated. Please use tf.compat.v1.assert_equal instead.
#
# WARNING:tensorflow:From pix2pix.py:299: The name tf.image.resize_images is deprecated. Please use tf.image.resize instead.
#
# WARNING:tensorflow:From pix2pix.py:301: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# WARNING:tensorflow:From pix2pix.py:314: batch (from tensorflow.python.training.input) is deprecated and will be removed in a future version.
# Instructions for updating:
# Queue-based input pipelines have been replaced by `tf.data`. Use `tf.data.Dataset.batch(batch_size)` (or `padded_batch(...)` if `dynamic_pad=True`).
# examples count = 106
# WARNING:tensorflow:From pix2pix.py:428: The name tf.variable_scope is deprecated. Please use tf.compat.v1.variable_scope instead.
#
# WARNING:tensorflow:From pix2pix.py:105: conv2d (from tensorflow.python.layers.convolutional) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.keras.layers.Conv2D` instead.
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.6/tensorflow_core/python/layers/convolutional.py:424: Layer.apply (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `layer.__call__` method instead.
# WARNING:tensorflow:From pix2pix.py:132: batch_normalization (from tensorflow.python.layers.normalization) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.BatchNormalization instead.  In particular, `tf.control_dependencies(tf.GraphKeys.UPDATE_OPS)` should not be used (consult the `tf.keras.layers.batch_normalization` documentation).
# WARNING:tensorflow:From pix2pix.py:116: conv2d_transpose (from tensorflow.python.layers.convolutional) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.keras.layers.Conv2DTranspose` instead.
# WARNING:tensorflow:From pix2pix.py:379: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# WARNING:tensorflow:From pix2pix.py:448: The name tf.log is deprecated. Please use tf.math.log instead.
#
# WARNING:tensorflow:From pix2pix.py:458: The name tf.trainable_variables is deprecated. Please use tf.compat.v1.trainable_variables instead.
#
# WARNING:tensorflow:From pix2pix.py:459: The name tf.train.AdamOptimizer is deprecated. Please use tf.compat.v1.train.AdamOptimizer instead.
#
# WARNING:tensorflow:From pix2pix.py:473: The name tf.train.get_or_create_global_step is deprecated. Please use tf.compat.v1.train.get_or_create_global_step instead.
#
# WARNING:tensorflow:From pix2pix.py:474: The name tf.assign is deprecated. Please use tf.compat.v1.assign instead.
#
# WARNING:tensorflow:From pix2pix.py:681: The name tf.summary.image is deprecated. Please use tf.compat.v1.summary.image instead.
#
# WARNING:tensorflow:From pix2pix.py:695: The name tf.summary.scalar is deprecated. Please use tf.compat.v1.summary.scalar instead.
#
# WARNING:tensorflow:From pix2pix.py:700: The name tf.summary.histogram is deprecated. Please use tf.compat.v1.summary.histogram instead.
#
# WARNING:tensorflow:From pix2pix.py:708: The name tf.train.Saver is deprecated. Please use tf.compat.v1.train.Saver instead.
#
# WARNING:tensorflow:From pix2pix.py:711: Supervisor.__init__ (from tensorflow.python.training.supervisor) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please switch to tf.train.MonitoredTrainingSession
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.6/tensorflow_core/python/ops/array_ops.py:1475: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# 2020-04-08 23:36:50.638343: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcuda.so.1
# 2020-04-08 23:36:50.640587: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-04-08 23:36:50.641133: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1639] Found device 0 with properties:
# name: Tesla P100-PCIE-16GB major: 6 minor: 0 memoryClockRate(GHz): 1.3285
# pciBusID: 0000:00:04.0
# 2020-04-08 23:36:50.641367: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2020-04-08 23:36:50.642671: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10
# 2020-04-08 23:36:50.644169: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcufft.so.10
# 2020-04-08 23:36:50.644448: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcurand.so.10
# 2020-04-08 23:36:50.645822: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusolver.so.10
# 2020-04-08 23:36:50.646439: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusparse.so.10
# 2020-04-08 23:36:50.649391: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2020-04-08 23:36:50.649493: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-04-08 23:36:50.650037: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-04-08 23:36:50.650556: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1767] Adding visible gpu devices: 0
# 2020-04-08 23:36:50.655061: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 2200000000 Hz
# 2020-04-08 23:36:50.655278: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x296abc0 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2020-04-08 23:36:50.655303: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
# 2020-04-08 23:36:50.742980: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-04-08 23:36:50.743625: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x296ad80 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2020-04-08 23:36:50.743650: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Tesla P100-PCIE-16GB, Compute Capability 6.0
# 2020-04-08 23:36:50.743803: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-04-08 23:36:50.744346: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1639] Found device 0 with properties:
# name: Tesla P100-PCIE-16GB major: 6 minor: 0 memoryClockRate(GHz): 1.3285
# pciBusID: 0000:00:04.0
# 2020-04-08 23:36:50.744396: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2020-04-08 23:36:50.744415: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10
# 2020-04-08 23:36:50.744433: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcufft.so.10
# 2020-04-08 23:36:50.744450: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcurand.so.10
# 2020-04-08 23:36:50.744467: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusolver.so.10
# 2020-04-08 23:36:50.744482: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusparse.so.10
# 2020-04-08 23:36:50.744499: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2020-04-08 23:36:50.744561: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-04-08 23:36:50.745087: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-04-08 23:36:50.745571: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1767] Adding visible gpu devices: 0
# 2020-04-08 23:36:50.745622: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2020-04-08 23:36:50.746601: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1180] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2020-04-08 23:36:50.746625: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1186]      0
# 2020-04-08 23:36:50.746642: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1199] 0:   N
# 2020-04-08 23:36:50.746743: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-04-08 23:36:50.747284: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-04-08 23:36:50.747773: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:39] Overriding allow_growth setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# 2020-04-08 23:36:50.747810: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1325] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 14974 MB memory) -> physical GPU (device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0)
# parameter_count = 57190084
# 2020-04-08 23:37:01.512238: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2020-04-08 23:37:05.860872: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10
# progress  epoch 1  step 49  image/sec 4.7  remaining 75m
# discrim_loss 0.56375766
# gen_loss_GAN 0.38862675
# gen_loss_L1 0.1404176
# recording summary
# progress  epoch 1  step 99  image/sec 5.5  remaining 63m
# discrim_loss 0.676785
# gen_loss_GAN 0.81795293
# gen_loss_L1 0.2172729
# progress  epoch 2  step 43  image/sec 7.2  remaining 48m
# discrim_loss 0.65700793
# gen_loss_GAN 1.2896725
# gen_loss_L1 0.2664567
# recording summary
# progress  epoch 2  step 93  image/sec 7.3  remaining 47m
# discrim_loss 0.6125453
# gen_loss_GAN 1.6544846
# gen_loss_L1 0.29566503
# progress  epoch 3  step 38  image/sec 8.3  remaining 41m
# discrim_loss 0.5527824
# gen_loss_GAN 1.8897003
# gen_loss_L1 0.31021672
# recording summary
# progress  epoch 3  step 88  image/sec 8.2  remaining 42m
# discrim_loss 0.5658322
# gen_loss_GAN 2.085541
# gen_loss_L1 0.32524326
# progress  epoch 4  step 31  image/sec 8.9  remaining 38m
# discrim_loss 0.5617864
# gen_loss_GAN 2.1953895
# gen_loss_L1 0.32556504
# recording summary
# progress  epoch 4  step 82  image/sec 8.8  remaining 39m
# discrim_loss 0.5671004
# gen_loss_GAN 2.2632442
# gen_loss_L1 0.3320461
# progress  epoch 5  step 25  image/sec 9.3  remaining 37m
# discrim_loss 0.60154897
# gen_loss_GAN 2.250009
# gen_loss_L1 0.33530882
# recording summary
# progress  epoch 5  step 76  image/sec 9.2  remaining 37m
# discrim_loss 0.59668225
# gen_loss_GAN 2.2559884
# gen_loss_L1 0.33150518
# progress  epoch 6  step 19  image/sec 9.6  remaining 35m
# discrim_loss 0.61775774
# gen_loss_GAN 2.2482932
# gen_loss_L1 0.33544034
# recording summary
# progress  epoch 6  step 69  image/sec 9.5  remaining 36m
# discrim_loss 0.61613107
# gen_loss_GAN 2.238891
# gen_loss_L1 0.3370076
# progress  epoch 7  step 13  image/sec 9.8  remaining 34m
# discrim_loss 0.62206584
# gen_loss_GAN 2.2167315
# gen_loss_L1 0.33827654
# recording summary
# progress  epoch 7  step 63  image/sec 9.7  remaining 35m
# discrim_loss 0.6124517
# gen_loss_GAN 2.2659886
# gen_loss_L1 0.33642918
# progress  epoch 8  step 7  image/sec 10.0  remaining 34m
# discrim_loss 0.5582264
# gen_loss_GAN 2.2504852
# gen_loss_L1 0.33516464
# recording summary
# progress  epoch 8  step 57  image/sec 9.8  remaining 34m
# discrim_loss 0.6248698
# gen_loss_GAN 2.2257657
# gen_loss_L1 0.33302242
# progress  epoch 9  step 1  image/sec 10.1  remaining 33m
# discrim_loss 0.5749408
# gen_loss_GAN 2.2439075
# gen_loss_L1 0.3361745
# recording summary
# progress  epoch 9  step 51  image/sec 10.0  remaining 33m
# discrim_loss 0.5923543
# gen_loss_GAN 2.2652674
# gen_loss_L1 0.3333082
# progress  epoch 9  step 101  image/sec 10.2  remaining 33m
# discrim_loss 0.58482516
# gen_loss_GAN 2.3234315
# gen_loss_L1 0.33781618
# recording summary
# progress  epoch 10  step 45  image/sec 10.1  remaining 33m
# discrim_loss 0.5737072
# gen_loss_GAN 2.345147
# gen_loss_L1 0.3391142
# progress  epoch 10  step 95  image/sec 10.3  remaining 32m
# discrim_loss 0.6195372
# gen_loss_GAN 2.2585459
# gen_loss_L1 0.33463874
# recording summary
# progress  epoch 11  step 40  image/sec 10.1  remaining 33m
# discrim_loss 0.57966954
# gen_loss_GAN 2.240602
# gen_loss_L1 0.33208516
# progress  epoch 11  step 89  image/sec 10.3  remaining 32m
# discrim_loss 0.56471086
# gen_loss_GAN 2.279527
# gen_loss_L1 0.34038335
# recording summary
# progress  epoch 12  step 33  image/sec 10.2  remaining 32m
# discrim_loss 0.5969108
# gen_loss_GAN 2.2466962
# gen_loss_L1 0.33587798
# progress  epoch 12  step 83  image/sec 10.4  remaining 31m
# discrim_loss 0.56131566
# gen_loss_GAN 2.3152666
# gen_loss_L1 0.33748043
# recording summary
# progress  epoch 13  step 27  image/sec 10.3  remaining 32m
# discrim_loss 0.6203959
# gen_loss_GAN 2.2622569
# gen_loss_L1 0.33332607
# progress  epoch 13  step 78  image/sec 10.4  remaining 31m
# discrim_loss 0.635221
# gen_loss_GAN 2.296984
# gen_loss_L1 0.33443853
# recording summary
# progress  epoch 14  step 21  image/sec 10.3  remaining 31m
# discrim_loss 0.6032403
# gen_loss_GAN 2.2655606
# gen_loss_L1 0.33200198
# progress  epoch 14  step 71  image/sec 10.5  remaining 31m
# discrim_loss 0.632079
# gen_loss_GAN 2.2651882
# gen_loss_L1 0.33029363
# recording summary
# progress  epoch 15  step 15  image/sec 10.4  remaining 31m
# discrim_loss 0.6616931
# gen_loss_GAN 2.3279357
# gen_loss_L1 0.3350117
# progress  epoch 15  step 66  image/sec 10.5  remaining 31m
# discrim_loss 0.6934645
# gen_loss_GAN 2.2574332
# gen_loss_L1 0.3240964
# recording summary
# progress  epoch 16  step 10  image/sec 10.4  remaining 31m
# discrim_loss 0.6288736
# gen_loss_GAN 2.2385201
# gen_loss_L1 0.32865992
# progress  epoch 16  step 59  image/sec 10.5  remaining 30m
# discrim_loss 0.6117314
# gen_loss_GAN 2.2193918
# gen_loss_L1 0.32393178
# recording summary
# progress  epoch 17  step 3  image/sec 10.4  remaining 31m
# discrim_loss 0.6477624
# gen_loss_GAN 2.262357
# gen_loss_L1 0.33525658
# progress  epoch 17  step 54  image/sec 10.6  remaining 30m
# discrim_loss 0.6519084
# gen_loss_GAN 2.2575967
# gen_loss_L1 0.33365437
# recording summary
# progress  epoch 17  step 103  image/sec 10.5  remaining 30m
# discrim_loss 0.6536512
# gen_loss_GAN 2.2557454
# gen_loss_L1 0.33071205
# progress  epoch 18  step 47  image/sec 10.6  remaining 30m
# discrim_loss 0.7279181
# gen_loss_GAN 2.184941
# gen_loss_L1 0.3246172
# recording summary
# progress  epoch 18  step 98  image/sec 10.5  remaining 30m
# discrim_loss 0.6727258
# gen_loss_GAN 2.1752064
# gen_loss_L1 0.32843357
# progress  epoch 19  step 41  image/sec 10.6  remaining 30m
# discrim_loss 0.6743884
# gen_loss_GAN 2.1680822
# gen_loss_L1 0.3228094
# recording summary
# progress  epoch 19  step 91  image/sec 10.5  remaining 30m
# discrim_loss 0.6671956
# gen_loss_GAN 2.1422002
# gen_loss_L1 0.32893905
# progress  epoch 20  step 35  image/sec 10.6  remaining 29m
# discrim_loss 0.68099535
# gen_loss_GAN 2.141405
# gen_loss_L1 0.32461947
# recording summary
# progress  epoch 20  step 86  image/sec 10.6  remaining 30m
# discrim_loss 0.6901019
# gen_loss_GAN 2.0880644
# gen_loss_L1 0.32209602
# progress  epoch 21  step 29  image/sec 10.7  remaining 29m
# discrim_loss 0.6541919
# gen_loss_GAN 2.1312165
# gen_loss_L1 0.3188782
# recording summary
# progress  epoch 21  step 80  image/sec 10.6  remaining 29m
# discrim_loss 0.6557904
# gen_loss_GAN 2.1304476
# gen_loss_L1 0.3179505
# progress  epoch 22  step 24  image/sec 10.7  remaining 29m
# discrim_loss 0.65250546
# gen_loss_GAN 2.2391756
# gen_loss_L1 0.32322204
# recording summary
# progress  epoch 22  step 74  image/sec 10.6  remaining 29m
# discrim_loss 0.67155886
# gen_loss_GAN 2.1696234
# gen_loss_L1 0.32247287
# progress  epoch 23  step 17  image/sec 10.7  remaining 29m
# discrim_loss 0.6910492
# gen_loss_GAN 2.170831
# gen_loss_L1 0.31511623
# recording summary
# progress  epoch 23  step 68  image/sec 10.6  remaining 29m
# discrim_loss 0.6616996
# gen_loss_GAN 2.151048
# gen_loss_L1 0.31404227
# progress  epoch 24  step 11  image/sec 10.7  remaining 29m
# discrim_loss 0.6814014
# gen_loss_GAN 2.163985
# gen_loss_L1 0.31674477
# recording summary
# progress  epoch 24  step 61  image/sec 10.6  remaining 29m
# discrim_loss 0.63771176
# gen_loss_GAN 2.219143
# gen_loss_L1 0.313261
# progress  epoch 25  step 5  image/sec 10.7  remaining 28m
# discrim_loss 0.5930395
# gen_loss_GAN 2.229405
# gen_loss_L1 0.3132332
# recording summary
# progress  epoch 25  step 55  image/sec 10.7  remaining 29m
# discrim_loss 0.65368634
# gen_loss_GAN 2.1666846
# gen_loss_L1 0.3164082
# progress  epoch 25  step 105  image/sec 10.7  remaining 28m
# discrim_loss 0.6699079
# gen_loss_GAN 2.1792963
# gen_loss_L1 0.31071034
# recording summary
# progress  epoch 26  step 49  image/sec 10.7  remaining 28m
# discrim_loss 0.66350234
# gen_loss_GAN 2.1392214
# gen_loss_L1 0.30791265
# progress  epoch 26  step 99  image/sec 10.8  remaining 28m
# discrim_loss 0.6532623
# gen_loss_GAN 2.1288364
# gen_loss_L1 0.3111529
# recording summary
# progress  epoch 27  step 43  image/sec 10.7  remaining 28m
# discrim_loss 0.60710275
# gen_loss_GAN 2.1163573
# gen_loss_L1 0.30950695
# progress  epoch 27  step 93  image/sec 10.8  remaining 28m
# discrim_loss 0.64865917
# gen_loss_GAN 2.127172
# gen_loss_L1 0.31146532
# recording summary
# progress  epoch 28  step 37  image/sec 10.7  remaining 28m
# discrim_loss 0.6786493
# gen_loss_GAN 2.1332922
# gen_loss_L1 0.3094745
# progress  epoch 28  step 87  image/sec 10.8  remaining 28m
# discrim_loss 0.7070695
# gen_loss_GAN 2.1972005
# gen_loss_L1 0.30819875
# recording summary
# progress  epoch 29  step 32  image/sec 10.7  remaining 28m
# discrim_loss 0.66999763
# gen_loss_GAN 2.1293328
# gen_loss_L1 0.3025636
# progress  epoch 29  step 81  image/sec 10.8  remaining 28m
# discrim_loss 0.6647034
# gen_loss_GAN 2.1621933
# gen_loss_L1 0.30434316
# recording summary
# progress  epoch 30  step 25  image/sec 10.7  remaining 28m
# discrim_loss 0.6686084
# gen_loss_GAN 2.1642072
# gen_loss_L1 0.3040955
# progress  epoch 30  step 75  image/sec 10.8  remaining 27m
# discrim_loss 0.64817995
# gen_loss_GAN 2.1521842
# gen_loss_L1 0.29643655
# recording summary
# progress  epoch 31  step 19  image/sec 10.7  remaining 27m
# discrim_loss 0.6772966
# gen_loss_GAN 2.1230834
# gen_loss_L1 0.30248034
# progress  epoch 31  step 69  image/sec 10.8  remaining 27m
# discrim_loss 0.72198135
# gen_loss_GAN 2.1057675
# gen_loss_L1 0.2933002
# recording summary
# progress  epoch 32  step 13  image/sec 10.7  remaining 27m
# discrim_loss 0.7161971
# gen_loss_GAN 2.115191
# gen_loss_L1 0.30132446
# progress  epoch 32  step 63  image/sec 10.8  remaining 27m
# discrim_loss 0.6622437
# gen_loss_GAN 2.1597817
# gen_loss_L1 0.30142105
# recording summary
# progress  epoch 33  step 7  image/sec 10.8  remaining 27m
# discrim_loss 0.6603375
# gen_loss_GAN 2.1260614
# gen_loss_L1 0.29754037
# progress  epoch 33  step 57  image/sec 10.8  remaining 27m
# discrim_loss 0.64240324
# gen_loss_GAN 2.102397
# gen_loss_L1 0.30062565
# recording summary
# progress  epoch 34  step 1  image/sec 10.8  remaining 27m
# discrim_loss 0.70744693
# gen_loss_GAN 2.132412
# gen_loss_L1 0.29432172
# progress  epoch 34  step 52  image/sec 10.8  remaining 27m
# discrim_loss 0.70389247
# gen_loss_GAN 2.0626693
# gen_loss_L1 0.2958823
# recording summary
# progress  epoch 34  step 101  image/sec 10.8  remaining 27m
# discrim_loss 0.75518763
# gen_loss_GAN 2.0094678
# gen_loss_L1 0.29274467
# progress  epoch 35  step 45  image/sec 10.8  remaining 26m
# discrim_loss 0.7042955
# gen_loss_GAN 2.0086803
# gen_loss_L1 0.29027888
# recording summary
# progress  epoch 35  step 95  image/sec 10.8  remaining 27m
# discrim_loss 0.7880517
# gen_loss_GAN 2.05085
# gen_loss_L1 0.2915124
# progress  epoch 36  step 39  image/sec 10.8  remaining 26m
# discrim_loss 0.76391655
# gen_loss_GAN 2.070471
# gen_loss_L1 0.28921264
# recording summary
# progress  epoch 36  step 89  image/sec 10.8  remaining 26m
# discrim_loss 0.7223868
# gen_loss_GAN 2.0314248
# gen_loss_L1 0.2869341
# progress  epoch 37  step 33  image/sec 10.8  remaining 26m
# discrim_loss 0.7464835
# gen_loss_GAN 2.011931
# gen_loss_L1 0.28683442
# recording summary
# progress  epoch 37  step 83  image/sec 10.8  remaining 26m
# discrim_loss 0.7360857
# gen_loss_GAN 2.0361288
# gen_loss_L1 0.28652224
# progress  epoch 38  step 28  image/sec 10.9  remaining 26m
# discrim_loss 0.728311
# gen_loss_GAN 1.9940683
# gen_loss_L1 0.28252715
# recording summary
# progress  epoch 38  step 77  image/sec 10.8  remaining 26m
# discrim_loss 0.6749245
# gen_loss_GAN 2.0597746
# gen_loss_L1 0.28354055
# progress  epoch 39  step 21  image/sec 10.9  remaining 26m
# discrim_loss 0.71010107
# gen_loss_GAN 2.0411813
# gen_loss_L1 0.28091654
# recording summary
# progress  epoch 39  step 72  image/sec 10.8  remaining 26m
# discrim_loss 0.70219076
# gen_loss_GAN 2.020593
# gen_loss_L1 0.2800725
# progress  epoch 40  step 15  image/sec 10.9  remaining 26m
# discrim_loss 0.68293613
# gen_loss_GAN 2.0236557
# gen_loss_L1 0.28594583
# recording summary
# progress  epoch 40  step 65  image/sec 10.8  remaining 26m
# discrim_loss 0.66869986
# gen_loss_GAN 2.0856583
# gen_loss_L1 0.28743592
# progress  epoch 41  step 10  image/sec 10.9  remaining 25m
# discrim_loss 0.72088265
# gen_loss_GAN 2.1118865
# gen_loss_L1 0.2823585
# recording summary
# progress  epoch 41  step 60  image/sec 10.8  remaining 26m
# discrim_loss 0.69024915
# gen_loss_GAN 2.1403675
# gen_loss_L1 0.27999726
# progress  epoch 42  step 3  image/sec 10.9  remaining 25m
# discrim_loss 0.7530958
# gen_loss_GAN 2.0627258
# gen_loss_L1 0.2757638
# recording summary
# progress  epoch 42  step 54  image/sec 10.8  remaining 25m
# discrim_loss 0.7571931
# gen_loss_GAN 2.0280092
# gen_loss_L1 0.27255747
# progress  epoch 42  step 104  image/sec 10.9  remaining 25m
# discrim_loss 0.76215494
# gen_loss_GAN 2.0792904
# gen_loss_L1 0.27651417
# recording summary
# progress  epoch 43  step 48  image/sec 10.8  remaining 25m
# discrim_loss 0.7325591
# gen_loss_GAN 2.0590656
# gen_loss_L1 0.27651215
# progress  epoch 43  step 98  image/sec 10.9  remaining 25m
# discrim_loss 0.71951675
# gen_loss_GAN 2.0302322
# gen_loss_L1 0.27638793
# recording summary
# progress  epoch 44  step 41  image/sec 10.8  remaining 25m
# discrim_loss 0.7476976
# gen_loss_GAN 2.0538392
# gen_loss_L1 0.27449772
# progress  epoch 44  step 91  image/sec 10.9  remaining 25m
# discrim_loss 0.7596
# gen_loss_GAN 2.0027769
# gen_loss_L1 0.2715459
# recording summary
# progress  epoch 45  step 35  image/sec 10.8  remaining 25m
# discrim_loss 0.7241964
# gen_loss_GAN 2.0172608
# gen_loss_L1 0.26957464
# progress  epoch 45  step 85  image/sec 10.9  remaining 25m
# discrim_loss 0.7695041
# gen_loss_GAN 1.9899348
# gen_loss_L1 0.2691831
# recording summary
# progress  epoch 46  step 29  image/sec 10.8  remaining 25m
# discrim_loss 0.7363501
# gen_loss_GAN 2.0178504
# gen_loss_L1 0.26968455
# progress  epoch 46  step 79  image/sec 10.9  remaining 25m
# discrim_loss 0.72631705
# gen_loss_GAN 2.0354998
# gen_loss_L1 0.26745114
# recording summary
# progress  epoch 47  step 23  image/sec 10.8  remaining 25m
# discrim_loss 0.7615402
# gen_loss_GAN 2.0124784
# gen_loss_L1 0.2746575
# progress  epoch 47  step 73  image/sec 10.9  remaining 24m
# discrim_loss 0.74080527
# gen_loss_GAN 2.0070868
# gen_loss_L1 0.26731175
# recording summary
# progress  epoch 48  step 17  image/sec 10.9  remaining 24m
# discrim_loss 0.7466009
# gen_loss_GAN 1.9858692
# gen_loss_L1 0.26861867
# saving model
# progress  epoch 48  step 67  image/sec 10.8  remaining 24m
# discrim_loss 0.72466445
# gen_loss_GAN 2.0348506
# gen_loss_L1 0.2662359
# recording summary
# progress  epoch 49  step 11  image/sec 10.8  remaining 24m
# discrim_loss 0.7355186
# gen_loss_GAN 1.9644465
# gen_loss_L1 0.2625332
# progress  epoch 49  step 61  image/sec 10.8  remaining 24m
# discrim_loss 0.7421503
# gen_loss_GAN 1.9707705
# gen_loss_L1 0.26314753
# recording summary
# progress  epoch 50  step 5  image/sec 10.8  remaining 24m
# discrim_loss 0.7351062
# gen_loss_GAN 2.031329
# gen_loss_L1 0.2632984
# progress  epoch 50  step 55  image/sec 10.8  remaining 24m
# discrim_loss 0.75767285
# gen_loss_GAN 2.007653
# gen_loss_L1 0.26197422
# recording summary
# progress  epoch 50  step 105  image/sec 10.8  remaining 24m
# discrim_loss 0.7865818
# gen_loss_GAN 1.9985368
# gen_loss_L1 0.26127496
# progress  epoch 51  step 49  image/sec 10.8  remaining 24m
# discrim_loss 0.8056615
# gen_loss_GAN 1.9895306
# gen_loss_L1 0.26008892
# recording summary
# progress  epoch 51  step 100  image/sec 10.8  remaining 24m
# discrim_loss 0.7723132
# gen_loss_GAN 1.9662409
# gen_loss_L1 0.2595416
# progress  epoch 52  step 43  image/sec 10.9  remaining 24m
# discrim_loss 0.7514536
# gen_loss_GAN 1.9564395
# gen_loss_L1 0.25955045
# recording summary
# progress  epoch 52  step 93  image/sec 10.8  remaining 24m
# discrim_loss 0.7192069
# gen_loss_GAN 1.9619648
# gen_loss_L1 0.25948268
# progress  epoch 53  step 38  image/sec 10.9  remaining 24m
# discrim_loss 0.704134
# gen_loss_GAN 1.9594244
# gen_loss_L1 0.25753042
# recording summary
# progress  epoch 53  step 87  image/sec 10.8  remaining 24m
# discrim_loss 0.7365862
# gen_loss_GAN 1.9588923
# gen_loss_L1 0.2546015
# progress  epoch 54  step 31  image/sec 10.9  remaining 23m
# discrim_loss 0.72652626
# gen_loss_GAN 1.9763997
# gen_loss_L1 0.2525342
# recording summary
# progress  epoch 54  step 81  image/sec 10.8  remaining 23m
# discrim_loss 0.7247648
# gen_loss_GAN 2.0053916
# gen_loss_L1 0.25713626
# progress  epoch 55  step 25  image/sec 10.9  remaining 23m
# discrim_loss 0.7562516
# gen_loss_GAN 1.9495144
# gen_loss_L1 0.25612473
# recording summary
# progress  epoch 55  step 75  image/sec 10.8  remaining 23m
# discrim_loss 0.78321266
# gen_loss_GAN 1.9592186
# gen_loss_L1 0.25303128
# progress  epoch 56  step 19  image/sec 10.9  remaining 23m
# discrim_loss 0.7471438
# gen_loss_GAN 2.0221846
# gen_loss_L1 0.25501454
# recording summary
# progress  epoch 56  step 69  image/sec 10.8  remaining 23m
# discrim_loss 0.73938084
# gen_loss_GAN 1.9883932
# gen_loss_L1 0.2540127
# progress  epoch 57  step 13  image/sec 10.9  remaining 23m
# discrim_loss 0.7222331
# gen_loss_GAN 1.9733089
# gen_loss_L1 0.25387505
# recording summary
# progress  epoch 57  step 63  image/sec 10.8  remaining 23m
# discrim_loss 0.75513583
# gen_loss_GAN 2.010344
# gen_loss_L1 0.25244683
# progress  epoch 58  step 7  image/sec 10.9  remaining 23m
# discrim_loss 0.74714303
# gen_loss_GAN 1.9971702
# gen_loss_L1 0.25359866
# recording summary
# progress  epoch 58  step 57  image/sec 10.8  remaining 23m
# discrim_loss 0.68829924
# gen_loss_GAN 2.0471697
# gen_loss_L1 0.25046802
# progress  epoch 59  step 2  image/sec 10.9  remaining 23m
# discrim_loss 0.77337795
# gen_loss_GAN 2.0525606
# gen_loss_L1 0.25260994
# recording summary
# progress  epoch 59  step 51  image/sec 10.8  remaining 23m
# discrim_loss 0.75941956
# gen_loss_GAN 2.053776
# gen_loss_L1 0.24871367
# progress  epoch 59  step 101  image/sec 10.9  remaining 22m
# discrim_loss 0.77503556
# gen_loss_GAN 2.0418172
# gen_loss_L1 0.25244802
# recording summary
# progress  epoch 60  step 45  image/sec 10.9  remaining 22m
# discrim_loss 0.73689693
# gen_loss_GAN 1.9626344
# gen_loss_L1 0.25037837
# progress  epoch 60  step 95  image/sec 10.9  remaining 22m
# discrim_loss 0.7560023
# gen_loss_GAN 1.9303728
# gen_loss_L1 0.24827535
# recording summary
# progress  epoch 61  step 39  image/sec 10.9  remaining 22m
# discrim_loss 0.7838852
# gen_loss_GAN 1.9655534
# gen_loss_L1 0.24664587
# progress  epoch 61  step 89  image/sec 10.9  remaining 22m
# discrim_loss 0.75789475
# gen_loss_GAN 1.9726636
# gen_loss_L1 0.2482766
# recording summary
# progress  epoch 62  step 33  image/sec 10.9  remaining 22m
# discrim_loss 0.7230259
# gen_loss_GAN 1.9716702
# gen_loss_L1 0.24669865
# progress  epoch 62  step 83  image/sec 10.9  remaining 22m
# discrim_loss 0.7594274
# gen_loss_GAN 1.9234608
# gen_loss_L1 0.24485126
# recording summary
# progress  epoch 63  step 27  image/sec 10.9  remaining 22m
# discrim_loss 0.683744
# gen_loss_GAN 1.966022
# gen_loss_L1 0.24878123
# progress  epoch 63  step 77  image/sec 10.9  remaining 22m
# discrim_loss 0.7292036
# gen_loss_GAN 1.9817584
# gen_loss_L1 0.24456704
# recording summary
# progress  epoch 64  step 21  image/sec 10.9  remaining 22m
# discrim_loss 0.7682819
# gen_loss_GAN 2.0089087
# gen_loss_L1 0.24455984
# progress  epoch 64  step 71  image/sec 10.9  remaining 22m
# discrim_loss 0.77095103
# gen_loss_GAN 1.9946302
# gen_loss_L1 0.24107423
# recording summary
# progress  epoch 65  step 15  image/sec 10.9  remaining 22m
# discrim_loss 0.78454846
# gen_loss_GAN 1.9806587
# gen_loss_L1 0.24061634
# progress  epoch 65  step 65  image/sec 10.9  remaining 21m
# discrim_loss 0.8149601
# gen_loss_GAN 1.9772847
# gen_loss_L1 0.2469013
# recording summary
# progress  epoch 66  step 9  image/sec 10.9  remaining 21m
# discrim_loss 0.7778392
# gen_loss_GAN 1.9661179
# gen_loss_L1 0.2431056
# progress  epoch 66  step 59  image/sec 10.9  remaining 21m
# discrim_loss 0.75906074
# gen_loss_GAN 1.9492612
# gen_loss_L1 0.24282603
# recording summary
# progress  epoch 67  step 4  image/sec 10.9  remaining 21m
# discrim_loss 0.7213938
# gen_loss_GAN 1.9718795
# gen_loss_L1 0.24201521
# progress  epoch 67  step 53  image/sec 10.9  remaining 21m
# discrim_loss 0.7398961
# gen_loss_GAN 2.0071766
# gen_loss_L1 0.24135268
# recording summary
# progress  epoch 67  step 104  image/sec 10.9  remaining 21m
# discrim_loss 0.77984005
# gen_loss_GAN 2.0038922
# gen_loss_L1 0.24136338
# progress  epoch 68  step 47  image/sec 10.9  remaining 21m
# discrim_loss 0.79483974
# gen_loss_GAN 1.9993377
# gen_loss_L1 0.24118407
# recording summary
# progress  epoch 68  step 97  image/sec 10.9  remaining 21m
# discrim_loss 0.7403074
# gen_loss_GAN 1.9863994
# gen_loss_L1 0.23769797
# progress  epoch 69  step 42  image/sec 10.9  remaining 21m
# discrim_loss 0.72700274
# gen_loss_GAN 1.9352539
# gen_loss_L1 0.23376356
# recording summary
# progress  epoch 69  step 91  image/sec 10.9  remaining 21m
# discrim_loss 0.7440527
# gen_loss_GAN 1.9256413
# gen_loss_L1 0.2341437
# progress  epoch 70  step 36  image/sec 10.9  remaining 21m
# discrim_loss 0.76876277
# gen_loss_GAN 1.9449342
# gen_loss_L1 0.24254395
# recording summary
# progress  epoch 70  step 86  image/sec 10.9  remaining 21m
# discrim_loss 0.79043883
# gen_loss_GAN 1.9517456
# gen_loss_L1 0.23964904
# progress  epoch 71  step 30  image/sec 10.9  remaining 20m
# discrim_loss 0.8009358
# gen_loss_GAN 1.9214114
# gen_loss_L1 0.23632175
# recording summary
# progress  epoch 71  step 80  image/sec 10.9  remaining 20m
# discrim_loss 0.7430126
# gen_loss_GAN 1.9423058
# gen_loss_L1 0.236322
# progress  epoch 72  step 24  image/sec 10.9  remaining 20m
# discrim_loss 0.7410372
# gen_loss_GAN 1.9270313
# gen_loss_L1 0.23829725
# recording summary
# progress  epoch 72  step 73  image/sec 10.9  remaining 20m
# discrim_loss 0.7782822
# gen_loss_GAN 2.0023186
# gen_loss_L1 0.23571262
# progress  epoch 73  step 17  image/sec 10.9  remaining 20m
# discrim_loss 0.8123703
# gen_loss_GAN 1.940474
# gen_loss_L1 0.23540586
# recording summary
# progress  epoch 73  step 68  image/sec 10.9  remaining 20m
# discrim_loss 0.7775785
# gen_loss_GAN 1.9533349
# gen_loss_L1 0.23401548
# progress  epoch 74  step 11  image/sec 10.9  remaining 20m
# discrim_loss 0.8067823
# gen_loss_GAN 1.940162
# gen_loss_L1 0.23617095
# recording summary
# progress  epoch 74  step 62  image/sec 10.9  remaining 20m
# discrim_loss 0.77538323
# gen_loss_GAN 1.9206644
# gen_loss_L1 0.23301007
# progress  epoch 75  step 6  image/sec 10.9  remaining 20m
# discrim_loss 0.7233795
# gen_loss_GAN 1.9479705
# gen_loss_L1 0.23219375
# recording summary
# progress  epoch 75  step 55  image/sec 10.9  remaining 20m
# discrim_loss 0.7884822
# gen_loss_GAN 1.968477
# gen_loss_L1 0.23188895
# progress  epoch 75  step 105  image/sec 10.9  remaining 20m
# discrim_loss 0.76426226
# gen_loss_GAN 1.9671563
# gen_loss_L1 0.22799985
# recording summary
# progress  epoch 76  step 49  image/sec 10.9  remaining 20m
# discrim_loss 0.7443758
# gen_loss_GAN 1.948024
# gen_loss_L1 0.2283429
# progress  epoch 76  step 99  image/sec 10.9  remaining 20m
# discrim_loss 0.75751615
# gen_loss_GAN 1.9956595
# gen_loss_L1 0.23120506
# recording summary
# progress  epoch 77  step 44  image/sec 10.9  remaining 20m
# discrim_loss 0.7573478
# gen_loss_GAN 1.9988369
# gen_loss_L1 0.22639567
# progress  epoch 77  step 93  image/sec 10.9  remaining 19m
# discrim_loss 0.7262716
# gen_loss_GAN 2.0028431
# gen_loss_L1 0.23028201
# recording summary
# progress  epoch 78  step 38  image/sec 10.9  remaining 19m
# discrim_loss 0.7247427
# gen_loss_GAN 1.984797
# gen_loss_L1 0.23232487
# progress  epoch 78  step 87  image/sec 10.9  remaining 19m
# discrim_loss 0.76126313
# gen_loss_GAN 1.9626479
# gen_loss_L1 0.22876514
# recording summary
# progress  epoch 79  step 31  image/sec 10.9  remaining 19m
# discrim_loss 0.77105546
# gen_loss_GAN 2.0401013
# gen_loss_L1 0.22722776
# progress  epoch 79  step 81  image/sec 10.9  remaining 19m
# discrim_loss 0.7743052
# gen_loss_GAN 2.023183
# gen_loss_L1 0.22863641
# recording summary
# progress  epoch 80  step 26  image/sec 10.9  remaining 19m
# discrim_loss 0.7986653
# gen_loss_GAN 1.9686383
# gen_loss_L1 0.22601558
# progress  epoch 80  step 75  image/sec 10.9  remaining 19m
# discrim_loss 0.7744927
# gen_loss_GAN 1.9999866
# gen_loss_L1 0.2258735
# recording summary
# progress  epoch 81  step 19  image/sec 10.9  remaining 19m
# discrim_loss 0.74220014
# gen_loss_GAN 2.0260646
# gen_loss_L1 0.2321325
# progress  epoch 81  step 69  image/sec 10.9  remaining 19m
# discrim_loss 0.7207807
# gen_loss_GAN 1.9851888
# gen_loss_L1 0.22667165
# recording summary
# progress  epoch 82  step 14  image/sec 10.9  remaining 19m
# discrim_loss 0.7123143
# gen_loss_GAN 2.032806
# gen_loss_L1 0.22932732
# progress  epoch 82  step 63  image/sec 10.9  remaining 19m
# discrim_loss 0.72736114
# gen_loss_GAN 2.0132513
# gen_loss_L1 0.226217
# recording summary
# progress  epoch 83  step 8  image/sec 10.9  remaining 19m
# discrim_loss 0.6814808
# gen_loss_GAN 2.0487413
# gen_loss_L1 0.22530414
# progress  epoch 83  step 58  image/sec 10.9  remaining 18m
# discrim_loss 0.7512854
# gen_loss_GAN 2.024899
# gen_loss_L1 0.22667502
# recording summary
# progress  epoch 84  step 1  image/sec 10.9  remaining 18m
# discrim_loss 0.7672229
# gen_loss_GAN 1.9536681
# gen_loss_L1 0.22257914
# progress  epoch 84  step 51  image/sec 11.0  remaining 18m
# discrim_loss 0.7744289
# gen_loss_GAN 1.944483
# gen_loss_L1 0.22541311
# recording summary
# progress  epoch 84  step 101  image/sec 10.9  remaining 18m
# discrim_loss 0.7427092
# gen_loss_GAN 1.9603511
# gen_loss_L1 0.2235484
# progress  epoch 85  step 46  image/sec 11.0  remaining 18m
# discrim_loss 0.7258466
# gen_loss_GAN 1.9503303
# gen_loss_L1 0.22296579
# recording summary
# progress  epoch 85  step 95  image/sec 10.9  remaining 18m
# discrim_loss 0.781212
# gen_loss_GAN 1.9551456
# gen_loss_L1 0.22319214
# progress  epoch 86  step 39  image/sec 11.0  remaining 18m
# discrim_loss 0.8081829
# gen_loss_GAN 1.984054
# gen_loss_L1 0.22408195
# recording summary
# progress  epoch 86  step 90  image/sec 10.9  remaining 18m
# discrim_loss 0.76968336
# gen_loss_GAN 1.9589666
# gen_loss_L1 0.2227126
# progress  epoch 87  step 33  image/sec 11.0  remaining 18m
# discrim_loss 0.7660079
# gen_loss_GAN 1.9727873
# gen_loss_L1 0.22318824
# recording summary
# progress  epoch 87  step 83  image/sec 10.9  remaining 18m
# discrim_loss 0.7122993
# gen_loss_GAN 2.0101418
# gen_loss_L1 0.22092044
# progress  epoch 88  step 27  image/sec 11.0  remaining 18m
# discrim_loss 0.72078073
# gen_loss_GAN 1.9972165
# gen_loss_L1 0.22141147
# recording summary
# progress  epoch 88  step 78  image/sec 10.9  remaining 18m
# discrim_loss 0.7346896
# gen_loss_GAN 1.9991511
# gen_loss_L1 0.2241681
# progress  epoch 89  step 21  image/sec 11.0  remaining 18m
# discrim_loss 0.72132754
# gen_loss_GAN 1.9467875
# gen_loss_L1 0.22372653
# recording summary
# progress  epoch 89  step 72  image/sec 10.9  remaining 17m
# discrim_loss 0.759952
# gen_loss_GAN 1.9634918
# gen_loss_L1 0.22509167
# progress  epoch 90  step 15  image/sec 11.0  remaining 17m
# discrim_loss 0.76579094
# gen_loss_GAN 1.9854468
# gen_loss_L1 0.21940938
# recording summary
# progress  epoch 90  step 65  image/sec 10.9  remaining 17m
# discrim_loss 0.7786801
# gen_loss_GAN 2.0406098
# gen_loss_L1 0.21905866
# progress  epoch 91  step 9  image/sec 11.0  remaining 17m
# discrim_loss 0.72560877
# gen_loss_GAN 2.01651
# gen_loss_L1 0.21839342
# recording summary
# progress  epoch 91  step 59  image/sec 10.9  remaining 17m
# discrim_loss 0.77798474
# gen_loss_GAN 2.0705752
# gen_loss_L1 0.22007118
# progress  epoch 92  step 3  image/sec 11.0  remaining 17m
# discrim_loss 0.7760996
# gen_loss_GAN 1.9990857
# gen_loss_L1 0.21530323
# recording summary
# progress  epoch 92  step 53  image/sec 10.9  remaining 17m
# discrim_loss 0.7565256
# gen_loss_GAN 2.0532286
# gen_loss_L1 0.21467613
# progress  epoch 92  step 104  image/sec 11.0  remaining 17m
# discrim_loss 0.75322074
# gen_loss_GAN 2.0619226
# gen_loss_L1 0.21667114
# recording summary
# progress  epoch 93  step 47  image/sec 10.9  remaining 17m
# discrim_loss 0.7332856
# gen_loss_GAN 1.9996419
# gen_loss_L1 0.21917024
# progress  epoch 93  step 98  image/sec 11.0  remaining 17m
# discrim_loss 0.7645449
# gen_loss_GAN 2.0540001
# gen_loss_L1 0.21972646
# recording summary
# progress  epoch 94  step 42  image/sec 10.9  remaining 17m
# discrim_loss 0.76646245
# gen_loss_GAN 1.9953653
# gen_loss_L1 0.2151814
# progress  epoch 94  step 91  image/sec 11.0  remaining 17m
# discrim_loss 0.7029901
# gen_loss_GAN 2.0601554
# gen_loss_L1 0.2196795
# recording summary
# progress  epoch 95  step 36  image/sec 10.9  remaining 17m
# discrim_loss 0.8005075
# gen_loss_GAN 2.0151887
# gen_loss_L1 0.22220048
# saving model
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.6/tensorflow_core/python/training/saver.py:963: remove_checkpoint (from tensorflow.python.training.checkpoint_management) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use standard file APIs to delete files with this prefix.
# progress  epoch 95  step 85  image/sec 10.9  remaining 16m
# discrim_loss 0.7814658
# gen_loss_GAN 1.9979217
# gen_loss_L1 0.21600711
# recording summary
# progress  epoch 96  step 29  image/sec 10.9  remaining 16m
# discrim_loss 0.7614945
# gen_loss_GAN 1.9820778
# gen_loss_L1 0.21483316
# progress  epoch 96  step 79  image/sec 10.9  remaining 16m
# discrim_loss 0.77435994
# gen_loss_GAN 1.9616088
# gen_loss_L1 0.21317355
# recording summary
# progress  epoch 97  step 23  image/sec 10.9  remaining 16m
# discrim_loss 0.77395815
# gen_loss_GAN 2.0351725
# gen_loss_L1 0.21451464
# progress  epoch 97  step 73  image/sec 10.9  remaining 16m
# discrim_loss 0.747761
# gen_loss_GAN 1.9945561
# gen_loss_L1 0.21245264
# recording summary
# progress  epoch 98  step 17  image/sec 10.9  remaining 16m
# discrim_loss 0.709332
# gen_loss_GAN 2.0304444
# gen_loss_L1 0.21453078
# progress  epoch 98  step 68  image/sec 10.9  remaining 16m
# discrim_loss 0.7521578
# gen_loss_GAN 1.9923068
# gen_loss_L1 0.21364973
# recording summary
# progress  epoch 99  step 11  image/sec 10.9  remaining 16m
# discrim_loss 0.7078501
# gen_loss_GAN 2.0108635
# gen_loss_L1 0.21671641
# progress  epoch 99  step 61  image/sec 10.9  remaining 16m
# discrim_loss 0.73274195
# gen_loss_GAN 1.9781559
# gen_loss_L1 0.21353394
# recording summary
# progress  epoch 100  step 6  image/sec 10.9  remaining 16m
# discrim_loss 0.72426116
# gen_loss_GAN 2.0125172
# gen_loss_L1 0.21543482
# progress  epoch 100  step 55  image/sec 10.9  remaining 16m
# discrim_loss 0.7354127
# gen_loss_GAN 1.9976596
# gen_loss_L1 0.21740562
# recording summary
# progress  epoch 100  step 105  image/sec 10.9  remaining 16m
# discrim_loss 0.72665876
# gen_loss_GAN 1.9763962
# gen_loss_L1 0.2129304
# progress  epoch 101  step 49  image/sec 10.9  remaining 16m
# discrim_loss 0.8462025
# gen_loss_GAN 1.9731592
# gen_loss_L1 0.21112871
# recording summary
# progress  epoch 101  step 99  image/sec 10.9  remaining 16m
# discrim_loss 0.79315186
# gen_loss_GAN 1.9586463
# gen_loss_L1 0.21143106
# progress  epoch 102  step 43  image/sec 10.9  remaining 15m
# discrim_loss 0.80210626
# gen_loss_GAN 2.0030775
# gen_loss_L1 0.21356967
# recording summary
# progress  epoch 102  step 94  image/sec 10.9  remaining 15m
# discrim_loss 0.8139751
# gen_loss_GAN 1.9869903
# gen_loss_L1 0.21244259
# progress  epoch 103  step 37  image/sec 10.9  remaining 15m
# discrim_loss 0.7592417
# gen_loss_GAN 1.9861957
# gen_loss_L1 0.21200971
# recording summary
# progress  epoch 103  step 87  image/sec 10.9  remaining 15m
# discrim_loss 0.70958614
# gen_loss_GAN 2.0378962
# gen_loss_L1 0.21338844
# progress  epoch 104  step 32  image/sec 10.9  remaining 15m
# discrim_loss 0.6982269
# gen_loss_GAN 2.0213368
# gen_loss_L1 0.21257769
# recording summary
# progress  epoch 104  step 81  image/sec 10.9  remaining 15m
# discrim_loss 0.7799444
# gen_loss_GAN 2.040705
# gen_loss_L1 0.21340501
# progress  epoch 105  step 25  image/sec 10.9  remaining 15m
# discrim_loss 0.7700445
# gen_loss_GAN 2.0022728
# gen_loss_L1 0.21219057
# recording summary
# progress  epoch 105  step 76  image/sec 10.9  remaining 15m
# discrim_loss 0.7560072
# gen_loss_GAN 1.9968809
# gen_loss_L1 0.21183948
# progress  epoch 106  step 19  image/sec 10.9  remaining 15m
# discrim_loss 0.77468085
# gen_loss_GAN 2.0036254
# gen_loss_L1 0.20909245
# recording summary
# progress  epoch 106  step 70  image/sec 10.9  remaining 15m
# discrim_loss 0.73270184
# gen_loss_GAN 2.0091593
# gen_loss_L1 0.21014531
# progress  epoch 107  step 14  image/sec 11.0  remaining 15m
# discrim_loss 0.7440603
# gen_loss_GAN 2.0196507
# gen_loss_L1 0.20855546
# recording summary
# progress  epoch 107  step 63  image/sec 10.9  remaining 15m
# discrim_loss 0.74066067
# gen_loss_GAN 2.0158122
# gen_loss_L1 0.20696826
# progress  epoch 108  step 7  image/sec 11.0  remaining 14m
# discrim_loss 0.70674765
# gen_loss_GAN 2.0328517
# gen_loss_L1 0.21038412
# recording summary
# progress  epoch 108  step 58  image/sec 10.9  remaining 14m
# discrim_loss 0.74065024
# gen_loss_GAN 2.0032723
# gen_loss_L1 0.21109699
# progress  epoch 109  step 1  image/sec 11.0  remaining 14m
# discrim_loss 0.7559145
# gen_loss_GAN 2.015139
# gen_loss_L1 0.20682333
# recording summary
# progress  epoch 109  step 51  image/sec 10.9  remaining 14m
# discrim_loss 0.7801588
# gen_loss_GAN 1.9928861
# gen_loss_L1 0.2064659
# progress  epoch 109  step 101  image/sec 11.0  remaining 14m
# discrim_loss 0.750866
# gen_loss_GAN 2.021707
# gen_loss_L1 0.20904791
# recording summary
# progress  epoch 110  step 45  image/sec 10.9  remaining 14m
# discrim_loss 0.8005052
# gen_loss_GAN 2.0011485
# gen_loss_L1 0.20885223
# progress  epoch 110  step 95  image/sec 11.0  remaining 14m
# discrim_loss 0.741395
# gen_loss_GAN 2.0003843
# gen_loss_L1 0.20738816
# recording summary
# progress  epoch 111  step 39  image/sec 10.9  remaining 14m
# discrim_loss 0.7401823
# gen_loss_GAN 1.9638852
# gen_loss_L1 0.20727676
# progress  epoch 111  step 89  image/sec 11.0  remaining 14m
# discrim_loss 0.7460467
# gen_loss_GAN 2.0430977
# gen_loss_L1 0.20718272
# recording summary
# progress  epoch 112  step 34  image/sec 10.9  remaining 14m
# discrim_loss 0.7833978
# gen_loss_GAN 2.0356057
# gen_loss_L1 0.20929062
# progress  epoch 112  step 83  image/sec 11.0  remaining 14m
# discrim_loss 0.808594
# gen_loss_GAN 1.9890461
# gen_loss_L1 0.20606372
# recording summary
# progress  epoch 113  step 28  image/sec 10.9  remaining 14m
# discrim_loss 0.7564342
# gen_loss_GAN 1.9919481
# gen_loss_L1 0.20950818
# progress  epoch 113  step 78  image/sec 11.0  remaining 14m
# discrim_loss 0.7277282
# gen_loss_GAN 1.9513239
# gen_loss_L1 0.20640174
# recording summary
# progress  epoch 114  step 22  image/sec 10.9  remaining 14m
# discrim_loss 0.7335615
# gen_loss_GAN 1.9903214
# gen_loss_L1 0.20333323
# progress  epoch 114  step 71  image/sec 11.0  remaining 13m
# discrim_loss 0.72666633
# gen_loss_GAN 2.008373
# gen_loss_L1 0.20656294
# recording summary
# progress  epoch 115  step 15  image/sec 10.9  remaining 13m
# discrim_loss 0.66453826
# gen_loss_GAN 2.0404243
# gen_loss_L1 0.20587447
# progress  epoch 115  step 66  image/sec 11.0  remaining 13m
# discrim_loss 0.6536808
# gen_loss_GAN 2.0466452
# gen_loss_L1 0.20399942
# recording summary
# progress  epoch 116  step 10  image/sec 10.9  remaining 13m
# discrim_loss 0.74479944
# gen_loss_GAN 2.0043008
# gen_loss_L1 0.20399815
# progress  epoch 116  step 59  image/sec 11.0  remaining 13m
# discrim_loss 0.7265069
# gen_loss_GAN 2.0086246
# gen_loss_L1 0.20284793
# recording summary
# progress  epoch 117  step 3  image/sec 10.9  remaining 13m
# discrim_loss 0.78235817
# gen_loss_GAN 2.0714004
# gen_loss_L1 0.20347133
# progress  epoch 117  step 53  image/sec 11.0  remaining 13m
# discrim_loss 0.7253491
# gen_loss_GAN 2.0500839
# gen_loss_L1 0.20584336
# recording summary
# progress  epoch 117  step 103  image/sec 10.9  remaining 13m
# discrim_loss 0.7111226
# gen_loss_GAN 2.0019143
# gen_loss_L1 0.20354354
# progress  epoch 118  step 47  image/sec 11.0  remaining 13m
# discrim_loss 0.7285613
# gen_loss_GAN 2.0178504
# gen_loss_L1 0.20418343
# ...
# discrim_loss 0.72705114
# gen_loss_GAN 1.9936862
# gen_loss_L1 0.19149531
# progress  epoch 146  step 80  image/sec 11.0  remaining 8m
# discrim_loss 0.7189835
# gen_loss_GAN 1.9934843
# gen_loss_L1 0.1896625
# recording summary
# progress  epoch 147  step 24  image/sec 10.9  remaining 8m
# discrim_loss 0.72048646
# gen_loss_GAN 2.0369966
# gen_loss_L1 0.19564076
# progress  epoch 147  step 73  image/sec 11.0  remaining 8m
# discrim_loss 0.69542736
# gen_loss_GAN 2.0486572
# gen_loss_L1 0.19349888
# recording summary
# progress  epoch 148  step 17  image/sec 10.9  remaining 8m
# discrim_loss 0.67291147
# gen_loss_GAN 2.0050461
# gen_loss_L1 0.19147624
# progress  epoch 148  step 67  image/sec 11.0  remaining 8m
# discrim_loss 0.7315931
# gen_loss_GAN 1.9994798
# gen_loss_L1 0.19311883
# recording summary
# progress  epoch 149  step 12  image/sec 10.9  remaining 8m
# discrim_loss 0.7778348
# gen_loss_GAN 2.0242448
# gen_loss_L1 0.19435719
# progress  epoch 149  step 62  image/sec 11.0  remaining 8m
# discrim_loss 0.72257584
# gen_loss_GAN 2.0522892
# gen_loss_L1 0.19436926
# recording summary
# progress  epoch 150  step 6  image/sec 10.9  remaining 8m
# discrim_loss 0.71794736
# gen_loss_GAN 2.0448344
# gen_loss_L1 0.19277638
# progress  epoch 150  step 55  image/sec 11.0  remaining 8m
# discrim_loss 0.7349872
# gen_loss_GAN 2.0406203
# gen_loss_L1 0.19174732
# recording summary
# progress  epoch 150  step 105  image/sec 10.9  remaining 8m
# discrim_loss 0.7109473
# gen_loss_GAN 2.0905616
# gen_loss_L1 0.19020076
# progress  epoch 151  step 49  image/sec 11.0  remaining 7m
# discrim_loss 0.7179189
# gen_loss_GAN 2.0927029
# gen_loss_L1 0.19050126
# recording summary
# progress  epoch 151  step 100  image/sec 10.9  remaining 7m
# discrim_loss 0.7542374
# gen_loss_GAN 2.075682
# gen_loss_L1 0.19052167
# progress  epoch 152  step 44  image/sec 11.0  remaining 7m
# discrim_loss 0.697717
# gen_loss_GAN 2.0899498
# gen_loss_L1 0.19189419
# recording summary
# progress  epoch 152  step 93  image/sec 10.9  remaining 7m
# discrim_loss 0.68734276
# gen_loss_GAN 2.1011167
# gen_loss_L1 0.19120435
# progress  epoch 153  step 37  image/sec 11.0  remaining 7m
# discrim_loss 0.698681
# gen_loss_GAN 2.0906234
# gen_loss_L1 0.19210693
# recording summary
# progress  epoch 153  step 87  image/sec 10.9  remaining 7m
# discrim_loss 0.71894616
# gen_loss_GAN 2.1312237
# gen_loss_L1 0.18932034
# progress  epoch 154  step 32  image/sec 11.0  remaining 7m
# discrim_loss 0.696729
# gen_loss_GAN 2.1223302
# gen_loss_L1 0.18851748
# recording summary
# progress  epoch 154  step 82  image/sec 10.9  remaining 7m
# discrim_loss 0.793139
# gen_loss_GAN 2.1208754
# gen_loss_L1 0.18946546
# progress  epoch 155  step 26  image/sec 11.0  remaining 7m
# discrim_loss 0.7749128
# gen_loss_GAN 2.1055052
# gen_loss_L1 0.19199617
# recording summary
# progress  epoch 155  step 75  image/sec 10.9  remaining 7m
# discrim_loss 0.7517335
# gen_loss_GAN 2.0605683
# gen_loss_L1 0.19034104
# progress  epoch 156  step 19  image/sec 11.0  remaining 7m
# discrim_loss 0.6962764
# gen_loss_GAN 2.0731173
# gen_loss_L1 0.1862543
# recording summary
# progress  epoch 156  step 69  image/sec 10.9  remaining 7m
# discrim_loss 0.68655556
# gen_loss_GAN 2.1036692
# gen_loss_L1 0.18856288
# progress  epoch 157  step 14  image/sec 11.0  remaining 7m
# discrim_loss 0.67191744
# gen_loss_GAN 2.1182296
# gen_loss_L1 0.18743728
# recording summary
# progress  epoch 157  step 63  image/sec 10.9  remaining 7m
# discrim_loss 0.7530954
# gen_loss_GAN 2.1038394
# gen_loss_L1 0.18766099
# progress  epoch 158  step 7  image/sec 11.0  remaining 6m
# discrim_loss 0.724829
# gen_loss_GAN 2.0823855
# gen_loss_L1 0.1882422
# recording summary
# progress  epoch 158  step 57  image/sec 10.9  remaining 6m
# discrim_loss 0.7213568
# gen_loss_GAN 2.0694203
# gen_loss_L1 0.18654972
# progress  epoch 159  step 1  image/sec 11.0  remaining 6m
# discrim_loss 0.72642446
# gen_loss_GAN 2.073247
# gen_loss_L1 0.18661876
# recording summary
# progress  epoch 159  step 51  image/sec 10.9  remaining 6m
# discrim_loss 0.72232294
# gen_loss_GAN 2.0504806
# gen_loss_L1 0.1857983
# progress  epoch 159  step 101  image/sec 11.0  remaining 6m
# discrim_loss 0.7074674
# gen_loss_GAN 2.0764577
# gen_loss_L1 0.18640444
# recording summary
# progress  epoch 160  step 45  image/sec 10.9  remaining 6m
# discrim_loss 0.6984705
# gen_loss_GAN 2.0774817
# gen_loss_L1 0.18699946
# progress  epoch 160  step 96  image/sec 11.0  remaining 6m
# discrim_loss 0.7170918
# gen_loss_GAN 2.0883245
# gen_loss_L1 0.18564706
# recording summary
# progress  epoch 161  step 40  image/sec 10.9  remaining 6m
# discrim_loss 0.7367779
# gen_loss_GAN 2.1587093
# gen_loss_L1 0.1859387
# progress  epoch 161  step 89  image/sec 11.0  remaining 6m
# discrim_loss 0.78599095
# gen_loss_GAN 2.1157944
# gen_loss_L1 0.18417479
# recording summary
# progress  epoch 162  step 33  image/sec 10.9  remaining 6m
# discrim_loss 0.77840203
# gen_loss_GAN 2.0869882
# gen_loss_L1 0.18660182
# progress  epoch 162  step 83  image/sec 11.0  remaining 6m
# discrim_loss 0.7711714
# gen_loss_GAN 2.0725746
# gen_loss_L1 0.1869143
# recording summary
# progress  epoch 163  step 27  image/sec 11.0  remaining 6m
# discrim_loss 0.757748
# gen_loss_GAN 2.1135905
# gen_loss_L1 0.18743874
# progress  epoch 163  step 77  image/sec 11.0  remaining 6m
# discrim_loss 0.7579429
# gen_loss_GAN 2.1304846
# gen_loss_L1 0.18598999
# recording summary
# progress  epoch 164  step 21  image/sec 11.0  remaining 5m
# discrim_loss 0.7483071
# gen_loss_GAN 2.0615199
# gen_loss_L1 0.18440616
# progress  epoch 164  step 71  image/sec 11.0  remaining 5m
# discrim_loss 0.704109
# gen_loss_GAN 2.0950112
# gen_loss_L1 0.18736488
# recording summary
# progress  epoch 165  step 15  image/sec 11.0  remaining 5m
# discrim_loss 0.7165154
# gen_loss_GAN 2.0949738
# gen_loss_L1 0.18597928
# progress  epoch 165  step 65  image/sec 11.0  remaining 5m
# discrim_loss 0.7119522
# gen_loss_GAN 2.1232193
# gen_loss_L1 0.18513523
# recording summary
# progress  epoch 166  step 10  image/sec 11.0  remaining 5m
# discrim_loss 0.7295656
# gen_loss_GAN 2.0939507
# gen_loss_L1 0.18694647
# progress  epoch 166  step 59  image/sec 11.0  remaining 5m
# discrim_loss 0.71013445
# gen_loss_GAN 2.0435488
# gen_loss_L1 0.18384963
# recording summary
# progress  epoch 167  step 3  image/sec 11.0  remaining 5m
# discrim_loss 0.7502049
# gen_loss_GAN 2.018011
# gen_loss_L1 0.18449263
# progress  epoch 167  step 53  image/sec 11.0  remaining 5m
# discrim_loss 0.70644414
# gen_loss_GAN 2.025214
# gen_loss_L1 0.18569548
# recording summary
# progress  epoch 167  step 103  image/sec 11.0  remaining 5m
# discrim_loss 0.7579913
# gen_loss_GAN 2.1008492
# gen_loss_L1 0.18393113
# progress  epoch 168  step 47  image/sec 11.0  remaining 5m
# discrim_loss 0.7282246
# gen_loss_GAN 2.0574975
# gen_loss_L1 0.18222615
# recording summary
# progress  epoch 168  step 98  image/sec 11.0  remaining 5m
# discrim_loss 0.69288003
# gen_loss_GAN 2.0662725
# gen_loss_L1 0.18469767
# progress  epoch 169  step 42  image/sec 11.0  remaining 5m
# discrim_loss 0.69654965
# gen_loss_GAN 2.0842829
# gen_loss_L1 0.18663505
# recording summary
# progress  epoch 169  step 91  image/sec 11.0  remaining 5m
# discrim_loss 0.716184
# gen_loss_GAN 2.0716252
# gen_loss_L1 0.18687014
# progress  epoch 170  step 35  image/sec 11.0  remaining 4m
# discrim_loss 0.7506612
# gen_loss_GAN 2.0410855
# gen_loss_L1 0.18487899
# recording summary
# progress  epoch 170  step 85  image/sec 11.0  remaining 4m
# discrim_loss 0.695153
# gen_loss_GAN 2.135636
# gen_loss_L1 0.18532766
# progress  epoch 171  step 29  image/sec 11.0  remaining 4m
# discrim_loss 0.7063319
# gen_loss_GAN 2.136772
# gen_loss_L1 0.18731968
# recording summary
# progress  epoch 171  step 80  image/sec 11.0  remaining 4m
# discrim_loss 0.7380451
# gen_loss_GAN 2.1377454
# gen_loss_L1 0.18441242
# progress  epoch 172  step 23  image/sec 11.0  remaining 4m
# discrim_loss 0.7066971
# gen_loss_GAN 2.071074
# gen_loss_L1 0.1819821
# recording summary
# progress  epoch 172  step 74  image/sec 11.0  remaining 4m
# discrim_loss 0.6978122
# gen_loss_GAN 2.1201158
# gen_loss_L1 0.18449011
# progress  epoch 173  step 17  image/sec 11.0  remaining 4m
# discrim_loss 0.7269548
# gen_loss_GAN 2.161765
# gen_loss_L1 0.18711235
# recording summary
# progress  epoch 173  step 68  image/sec 11.0  remaining 4m
# discrim_loss 0.7234319
# gen_loss_GAN 2.165016
# gen_loss_L1 0.18726325
# progress  epoch 174  step 11  image/sec 11.0  remaining 4m
# discrim_loss 0.72472334
# gen_loss_GAN 2.1086454
# gen_loss_L1 0.18433638
# recording summary
# progress  epoch 174  step 61  image/sec 11.0  remaining 4m
# discrim_loss 0.7354101
# gen_loss_GAN 2.1316018
# gen_loss_L1 0.18460508
# progress  epoch 175  step 5  image/sec 11.0  remaining 4m
# discrim_loss 0.78204405
# gen_loss_GAN 2.1094787
# gen_loss_L1 0.18294404
# recording summary
# progress  epoch 175  step 55  image/sec 11.0  remaining 4m
# discrim_loss 0.79405105
# gen_loss_GAN 2.0376537
# gen_loss_L1 0.18046936
# progress  epoch 175  step 105  image/sec 11.0  remaining 4m
# discrim_loss 0.73318875
# gen_loss_GAN 2.0767162
# gen_loss_L1 0.18184067
# recording summary
# progress  epoch 176  step 50  image/sec 11.0  remaining 3m
# discrim_loss 0.70836294
# gen_loss_GAN 2.0865977
# gen_loss_L1 0.1820279
# progress  epoch 176  step 99  image/sec 11.0  remaining 3m
# discrim_loss 0.7492939
# gen_loss_GAN 2.1056263
# gen_loss_L1 0.18288484
# recording summary
# progress  epoch 177  step 43  image/sec 11.0  remaining 3m
# discrim_loss 0.8446205
# gen_loss_GAN 2.1478176
# gen_loss_L1 0.18055385
# progress  epoch 177  step 93  image/sec 11.0  remaining 3m
# discrim_loss 0.77116096
# gen_loss_GAN 2.1074388
# gen_loss_L1 0.18145432
# recording summary
# progress  epoch 178  step 37  image/sec 11.0  remaining 3m
# discrim_loss 0.74523145
# gen_loss_GAN 2.1581357
# gen_loss_L1 0.18191276
# progress  epoch 178  step 87  image/sec 11.0  remaining 3m
# discrim_loss 0.70432174
# gen_loss_GAN 2.1510558
# gen_loss_L1 0.18089789
# recording summary
# progress  epoch 179  step 32  image/sec 11.0  remaining 3m
# discrim_loss 0.6649837
# gen_loss_GAN 2.138226
# gen_loss_L1 0.18354334
# progress  epoch 179  step 81  image/sec 11.0  remaining 3m
# discrim_loss 0.6717574
# gen_loss_GAN 2.1204922
# gen_loss_L1 0.18467931
# recording summary
# progress  epoch 180  step 25  image/sec 11.0  remaining 3m
# discrim_loss 0.70278037
# gen_loss_GAN 2.1235616
# gen_loss_L1 0.17937347
# progress  epoch 180  step 75  image/sec 11.0  remaining 3m
# discrim_loss 0.68941027
# gen_loss_GAN 2.1452491
# gen_loss_L1 0.1814542
# recording summary
# progress  epoch 181  step 19  image/sec 11.0  remaining 3m
# discrim_loss 0.7045281
# gen_loss_GAN 2.1498258
# gen_loss_L1 0.18203142
# progress  epoch 181  step 69  image/sec 11.0  remaining 3m
# discrim_loss 0.78887993
# gen_loss_GAN 2.1353195
# gen_loss_L1 0.18198071
# recording summary
# progress  epoch 182  step 14  image/sec 11.0  remaining 3m
# discrim_loss 0.7445078
# gen_loss_GAN 2.169974
# gen_loss_L1 0.18077171
# progress  epoch 182  step 64  image/sec 11.0  remaining 2m
# discrim_loss 0.7140608
# gen_loss_GAN 2.1208644
# gen_loss_L1 0.18337663
# recording summary
# progress  epoch 183  step 8  image/sec 11.0  remaining 2m
# discrim_loss 0.6970599
# gen_loss_GAN 2.087155
# gen_loss_L1 0.18082015
# progress  epoch 183  step 58  image/sec 11.0  remaining 2m
# discrim_loss 0.7487042
# gen_loss_GAN 2.121508
# gen_loss_L1 0.1808998
# recording summary
# progress  epoch 184  step 1  image/sec 11.0  remaining 2m
# discrim_loss 0.7297779
# gen_loss_GAN 2.137726
# gen_loss_L1 0.17962223
# progress  epoch 184  step 51  image/sec 11.0  remaining 2m
# discrim_loss 0.7073084
# gen_loss_GAN 2.1260073
# gen_loss_L1 0.17883602
# recording summary
# progress  epoch 184  step 101  image/sec 11.0  remaining 2m
# discrim_loss 0.6966747
# gen_loss_GAN 2.174232
# gen_loss_L1 0.17995737
# progress  epoch 185  step 45  image/sec 11.0  remaining 2m
# discrim_loss 0.70524055
# gen_loss_GAN 2.1588268
# gen_loss_L1 0.17895657
# recording summary
# progress  epoch 185  step 95  image/sec 11.0  remaining 2m
# discrim_loss 0.70953035
# gen_loss_GAN 2.140618
# gen_loss_L1 0.18149672
# progress  epoch 186  step 39  image/sec 11.0  remaining 2m
# discrim_loss 0.74714845
# gen_loss_GAN 2.1336646
# gen_loss_L1 0.18063644
# recording summary
# progress  epoch 186  step 89  image/sec 11.0  remaining 2m
# discrim_loss 0.7258497
# gen_loss_GAN 2.145636
# gen_loss_L1 0.17823425
# progress  epoch 187  step 33  image/sec 11.0  remaining 2m
# discrim_loss 0.69139093
# gen_loss_GAN 2.168609
# gen_loss_L1 0.17823029
# recording summary
# progress  epoch 187  step 83  image/sec 11.0  remaining 2m
# discrim_loss 0.6793902
# gen_loss_GAN 2.1608348
# gen_loss_L1 0.17471115
# progress  epoch 188  step 27  image/sec 11.0  remaining 2m
# discrim_loss 0.6734473
# gen_loss_GAN 2.180969
# gen_loss_L1 0.17918952
# recording summary
# progress  epoch 188  step 77  image/sec 11.0  remaining 1m
# discrim_loss 0.7004678
# gen_loss_GAN 2.1918364
# gen_loss_L1 0.17729056
# progress  epoch 189  step 21  image/sec 11.0  remaining 1m
# discrim_loss 0.68580437
# gen_loss_GAN 2.1739311
# gen_loss_L1 0.17565726
# recording summary
# progress  epoch 189  step 72  image/sec 11.0  remaining 1m
# discrim_loss 0.67340267
# gen_loss_GAN 2.2148623
# gen_loss_L1 0.17689224
# saving model
# progress  epoch 190  step 16  image/sec 11.0  remaining 1m
# discrim_loss 0.68480057
# gen_loss_GAN 2.2042642
# gen_loss_L1 0.1796142
# recording summary
# progress  epoch 190  step 65  image/sec 11.0  remaining 1m
# discrim_loss 0.65130323
# gen_loss_GAN 2.199286
# gen_loss_L1 0.17564689
# progress  epoch 191  step 9  image/sec 11.0  remaining 1m
# discrim_loss 0.64566517
# gen_loss_GAN 2.2145414
# gen_loss_L1 0.17939661
# recording summary
# progress  epoch 191  step 59  image/sec 11.0  remaining 1m
# discrim_loss 0.64295244
# gen_loss_GAN 2.224959
# gen_loss_L1 0.1821226
# progress  epoch 192  step 4  image/sec 11.0  remaining 1m
# discrim_loss 0.70008725
# gen_loss_GAN 2.1964397
# gen_loss_L1 0.1800169
# recording summary
# progress  epoch 192  step 54  image/sec 11.0  remaining 1m
# discrim_loss 0.7098723
# gen_loss_GAN 2.180312
# gen_loss_L1 0.1789624
# progress  epoch 192  step 103  image/sec 11.0  remaining 1m
# discrim_loss 0.7173269
# gen_loss_GAN 2.1610322
# gen_loss_L1 0.1786791
# recording summary
# progress  epoch 193  step 47  image/sec 11.0  remaining 1m
# discrim_loss 0.7447184
# gen_loss_GAN 2.188565
# gen_loss_L1 0.17705363
# progress  epoch 193  step 97  image/sec 11.0  remaining 1m
# discrim_loss 0.6940525
# gen_loss_GAN 2.1900303
# gen_loss_L1 0.17800964
# recording summary
# progress  epoch 194  step 42  image/sec 11.0  remaining 1m
# discrim_loss 0.74755496
# gen_loss_GAN 2.1856313
# gen_loss_L1 0.17643902
# progress  epoch 194  step 91  image/sec 11.0  remaining 0m
# discrim_loss 0.7456286
# gen_loss_GAN 2.1229932
# gen_loss_L1 0.17822456
# recording summary
# progress  epoch 195  step 35  image/sec 11.0  remaining 0m
# discrim_loss 0.7193324
# gen_loss_GAN 2.17852
# gen_loss_L1 0.17944412
# progress  epoch 195  step 86  image/sec 11.0  remaining 0m
# discrim_loss 0.6992115
# gen_loss_GAN 2.1631634
# gen_loss_L1 0.17847173
# recording summary
# progress  epoch 196  step 29  image/sec 11.0  remaining 0m
# discrim_loss 0.7190069
# gen_loss_GAN 2.1443408
# gen_loss_L1 0.17706071
# progress  epoch 196  step 79  image/sec 11.0  remaining 0m
# discrim_loss 0.76358426
# gen_loss_GAN 2.1929338
# gen_loss_L1 0.1757801
# recording summary
# progress  epoch 197  step 24  image/sec 11.0  remaining 0m
# discrim_loss 0.7562259
# gen_loss_GAN 2.1552324
# gen_loss_L1 0.17916632
# progress  epoch 197  step 73  image/sec 11.0  remaining 0m
# discrim_loss 0.7004413
# gen_loss_GAN 2.1828613
# gen_loss_L1 0.1754045
# recording summary
# progress  epoch 198  step 18  image/sec 11.0  remaining 0m
# discrim_loss 0.70467985
# gen_loss_GAN 2.163379
# gen_loss_L1 0.17698522
# progress  epoch 198  step 67  image/sec 11.0  remaining 0m
# discrim_loss 0.7220485
# gen_loss_GAN 2.1531591
# gen_loss_L1 0.17588969
# recording summary
# progress  epoch 199  step 12  image/sec 11.0  remaining 0m
# discrim_loss 0.759034
# gen_loss_GAN 2.1711516
# gen_loss_L1 0.17568406
# progress  epoch 199  step 61  image/sec 11.0  remaining 0m
# discrim_loss 0.81590503
# gen_loss_GAN 2.2093866
# gen_loss_L1 0.1753985
# recording summary
# progress  epoch 200  step 6  image/sec 11.0  remaining 0m
# discrim_loss 0.74459463
# gen_loss_GAN 2.2078757
# gen_loss_L1 0.17403078
# progress  epoch 200  step 56  image/sec 11.0  remaining 0m
# discrim_loss 0.7104013
# gen_loss_GAN 2.2092328
# gen_loss_L1 0.17432676
# recording summary
# progress  epoch 200  step 105  image/sec 11.0  remaining 0m
# discrim_loss 0.66899276
# gen_loss_GAN 2.2171674
# gen_loss_L1 0.17579654
# saving model

# %%
# !python pix2pix.py \
  --mode test \
  --output_dir facades_test \
  --input_dir facades/val \
  --checkpoint facades_train
# Out:
# WARNING:tensorflow:From pix2pix.py:540: The name tf.set_random_seed is deprecated. Please use tf.compat.v1.set_random_seed instead.
#
# loaded lab_colorization = False
# loaded ndf = 64
# loaded ngf = 64
# loaded which_direction = BtoA
# aspect_ratio = 1.0
# batch_size = 1
# beta1 = 0.5
# checkpoint = facades_train
# display_freq = 0
# flip = False
# gan_weight = 1.0
# input_dir = facades/val
# l1_weight = 100.0
# lab_colorization = False
# lr = 0.0002
# max_epochs = None
# max_steps = None
# mode = test
# ndf = 64
# ngf = 64
# output_dir = facades_test
# output_filetype = png
# progress_freq = 50
# save_freq = 5000
# scale_size = 256
# seed = 51276838
# separable_conv = False
# summary_freq = 100
# trace_freq = 0
# which_direction = BtoA
# WARNING:tensorflow:From pix2pix.py:258: string_input_producer (from tensorflow.python.training.input) is deprecated and will be removed in a future version.
# Instructions for updating:
# Queue-based input pipelines have been replaced by `tf.data`. Use `tf.data.Dataset.from_tensor_slices(string_tensor).shuffle(tf.shape(input_tensor, out_type=tf.int64)[0]).repeat(num_epochs)`. If `shuffle=False`, omit the `.shuffle(...)`.
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.6/tensorflow_core/python/training/input.py:277: input_producer (from tensorflow.python.training.input) is deprecated and will be removed in a future version.
# Instructions for updating:
# Queue-based input pipelines have been replaced by `tf.data`. Use `tf.data.Dataset.from_tensor_slices(input_tensor).shuffle(tf.shape(input_tensor, out_type=tf.int64)[0]).repeat(num_epochs)`. If `shuffle=False`, omit the `.shuffle(...)`.
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.6/tensorflow_core/python/training/input.py:189: limit_epochs (from tensorflow.python.training.input) is deprecated and will be removed in a future version.
# Instructions for updating:
# Queue-based input pipelines have been replaced by `tf.data`. Use `tf.data.Dataset.from_tensors(tensor).repeat(num_epochs)`.
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.6/tensorflow_core/python/training/input.py:198: QueueRunner.__init__ (from tensorflow.python.training.queue_runner_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# To construct input pipelines, use the `tf.data` module.
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.6/tensorflow_core/python/training/input.py:198: add_queue_runner (from tensorflow.python.training.queue_runner_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# To construct input pipelines, use the `tf.data` module.
# WARNING:tensorflow:From pix2pix.py:259: WholeFileReader.__init__ (from tensorflow.python.ops.io_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Queue-based input pipelines have been replaced by `tf.data`. Use `tf.data.Dataset.map(tf.read_file)`.
# WARNING:tensorflow:From pix2pix.py:264: The name tf.assert_equal is deprecated. Please use tf.compat.v1.assert_equal instead.
#
# WARNING:tensorflow:From pix2pix.py:299: The name tf.image.resize_images is deprecated. Please use tf.image.resize instead.
#
# WARNING:tensorflow:From pix2pix.py:301: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# WARNING:tensorflow:From pix2pix.py:314: batch (from tensorflow.python.training.input) is deprecated and will be removed in a future version.
# Instructions for updating:
# Queue-based input pipelines have been replaced by `tf.data`. Use `tf.data.Dataset.batch(batch_size)` (or `padded_batch(...)` if `dynamic_pad=True`).
# examples count = 100
# WARNING:tensorflow:From pix2pix.py:428: The name tf.variable_scope is deprecated. Please use tf.compat.v1.variable_scope instead.
#
# WARNING:tensorflow:From pix2pix.py:105: conv2d (from tensorflow.python.layers.convolutional) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.keras.layers.Conv2D` instead.
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.6/tensorflow_core/python/layers/convolutional.py:424: Layer.apply (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `layer.__call__` method instead.
# WARNING:tensorflow:From pix2pix.py:132: batch_normalization (from tensorflow.python.layers.normalization) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.BatchNormalization instead.  In particular, `tf.control_dependencies(tf.GraphKeys.UPDATE_OPS)` should not be used (consult the `tf.keras.layers.batch_normalization` documentation).
# WARNING:tensorflow:From pix2pix.py:116: conv2d_transpose (from tensorflow.python.layers.convolutional) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.keras.layers.Conv2DTranspose` instead.
# WARNING:tensorflow:From pix2pix.py:379: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# WARNING:tensorflow:From pix2pix.py:448: The name tf.log is deprecated. Please use tf.math.log instead.
#
# WARNING:tensorflow:From pix2pix.py:458: The name tf.trainable_variables is deprecated. Please use tf.compat.v1.trainable_variables instead.
#
# WARNING:tensorflow:From pix2pix.py:459: The name tf.train.AdamOptimizer is deprecated. Please use tf.compat.v1.train.AdamOptimizer instead.
#
# WARNING:tensorflow:From pix2pix.py:473: The name tf.train.get_or_create_global_step is deprecated. Please use tf.compat.v1.train.get_or_create_global_step instead.
#
# WARNING:tensorflow:From pix2pix.py:474: The name tf.assign is deprecated. Please use tf.compat.v1.assign instead.
#
# WARNING:tensorflow:From pix2pix.py:681: The name tf.summary.image is deprecated. Please use tf.compat.v1.summary.image instead.
#
# WARNING:tensorflow:From pix2pix.py:695: The name tf.summary.scalar is deprecated. Please use tf.compat.v1.summary.scalar instead.
#
# WARNING:tensorflow:From pix2pix.py:700: The name tf.summary.histogram is deprecated. Please use tf.compat.v1.summary.histogram instead.
#
# WARNING:tensorflow:From pix2pix.py:708: The name tf.train.Saver is deprecated. Please use tf.compat.v1.train.Saver instead.
#
# WARNING:tensorflow:From pix2pix.py:711: Supervisor.__init__ (from tensorflow.python.training.supervisor) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please switch to tf.train.MonitoredTrainingSession
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.6/tensorflow_core/python/ops/array_ops.py:1475: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# 2020-04-09 00:10:39.089841: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcuda.so.1
# 2020-04-09 00:10:39.092241: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-04-09 00:10:39.092774: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1639] Found device 0 with properties:
# name: Tesla P100-PCIE-16GB major: 6 minor: 0 memoryClockRate(GHz): 1.3285
# pciBusID: 0000:00:04.0
# 2020-04-09 00:10:39.093007: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2020-04-09 00:10:39.094336: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10
# 2020-04-09 00:10:39.095786: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcufft.so.10
# 2020-04-09 00:10:39.096086: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcurand.so.10
# 2020-04-09 00:10:39.097457: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusolver.so.10
# 2020-04-09 00:10:39.098244: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusparse.so.10
# 2020-04-09 00:10:39.101716: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2020-04-09 00:10:39.101819: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-04-09 00:10:39.102371: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-04-09 00:10:39.102883: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1767] Adding visible gpu devices: 0
# 2020-04-09 00:10:39.107663: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 2200000000 Hz
# 2020-04-09 00:10:39.107854: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x1adca00 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2020-04-09 00:10:39.107879: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
# 2020-04-09 00:10:39.204566: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-04-09 00:10:39.205261: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x1addb80 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2020-04-09 00:10:39.205292: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Tesla P100-PCIE-16GB, Compute Capability 6.0
# 2020-04-09 00:10:39.205455: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-04-09 00:10:39.206016: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1639] Found device 0 with properties:
# name: Tesla P100-PCIE-16GB major: 6 minor: 0 memoryClockRate(GHz): 1.3285
# pciBusID: 0000:00:04.0
# 2020-04-09 00:10:39.206091: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2020-04-09 00:10:39.206121: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10
# 2020-04-09 00:10:39.206140: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcufft.so.10
# 2020-04-09 00:10:39.206157: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcurand.so.10
# 2020-04-09 00:10:39.206174: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusolver.so.10
# 2020-04-09 00:10:39.206190: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusparse.so.10
# 2020-04-09 00:10:39.206208: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2020-04-09 00:10:39.206270: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-04-09 00:10:39.206786: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-04-09 00:10:39.207286: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1767] Adding visible gpu devices: 0
# 2020-04-09 00:10:39.207347: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2020-04-09 00:10:39.208311: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1180] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2020-04-09 00:10:39.208337: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1186]      0
# 2020-04-09 00:10:39.208347: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1199] 0:   N
# 2020-04-09 00:10:39.208450: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-04-09 00:10:39.208974: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-04-09 00:10:39.209523: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:39] Overriding allow_growth setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# 2020-04-09 00:10:39.209567: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1325] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 14974 MB memory) -> physical GPU (device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0)
# parameter_count = 57190084
# loading model from checkpoint
# 2020-04-09 00:10:44.594695: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2020-04-09 00:10:45.644814: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10
# evaluated image 1
# evaluated image 2
# evaluated image 3
# evaluated image 4
# evaluated image 5
# evaluated image 6
# evaluated image 7
# evaluated image 8
# evaluated image 9
# evaluated image 10
# evaluated image 11
# evaluated image 12
# evaluated image 13
# evaluated image 14
# evaluated image 15
# evaluated image 16
# evaluated image 17
# evaluated image 18
# evaluated image 19
# evaluated image 20
# evaluated image 21
# evaluated image 22
# evaluated image 23
# evaluated image 24
# evaluated image 25
# evaluated image 26
# evaluated image 27
# evaluated image 28
# evaluated image 29
# evaluated image 30
# evaluated image 31
# evaluated image 32
# evaluated image 33
# evaluated image 34
# evaluated image 35
# evaluated image 36
# evaluated image 37
# evaluated image 38
# evaluated image 39
# evaluated image 40
# evaluated image 41
# evaluated image 42
# evaluated image 43
# evaluated image 44
# evaluated image 45
# evaluated image 46
# evaluated image 47
# evaluated image 48
# evaluated image 49
# evaluated image 50
# evaluated image 51
# evaluated image 52
# evaluated image 53
# evaluated image 54
# evaluated image 55
# evaluated image 56
# evaluated image 57
# evaluated image 58
# evaluated image 59
# evaluated image 60
# evaluated image 61
# evaluated image 62
# evaluated image 63
# evaluated image 64
# evaluated image 65
# evaluated image 66
# evaluated image 67
# evaluated image 68
# evaluated image 69
# evaluated image 70
# evaluated image 71
# evaluated image 72
# evaluated image 73
# evaluated image 74
# evaluated image 75
# evaluated image 76
# evaluated image 77
# evaluated image 78
# evaluated image 79
# evaluated image 80
# evaluated image 81
# evaluated image 82
# evaluated image 83
# evaluated image 84
# evaluated image 85
# evaluated image 86
# evaluated image 87
# evaluated image 88
# evaluated image 89
# evaluated image 90
# evaluated image 91
# evaluated image 92
# evaluated image 93
# evaluated image 94
# evaluated image 95
# evaluated image 96
# evaluated image 97
# evaluated image 98
# evaluated image 99
# evaluated image 100
# wrote index at facades_test/index.html
# rate 0.08401415824890136
