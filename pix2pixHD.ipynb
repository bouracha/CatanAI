# %% [markdown]
# <a href="https://colab.research.google.com/github/bouracha/CatanAI/blob/master/pix2pixHD.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !nvidia-smi
# Out:
# Fri Apr 10 10:53:38 2020
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 440.64.00    Driver Version: 418.67       CUDA Version: 10.1     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   60C    P8    10W /  70W |      0MiB / 15079MiB |      0%      Default |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                       GPU Memory |
# ...

# %%
# !nvcc --version
# Out:
# nvcc: NVIDIA (R) Cuda compiler driver
# Copyright (c) 2005-2019 NVIDIA Corporation
# Built on Sun_Jul_28_19:07:16_PDT_2019
# Cuda compilation tools, release 10.1, V10.1.243

# %%
import tensorflow as tf
tf.test.gpu_device_name()
# Out:
# '/device:GPU:0'

# %% [markdown]
# ## Get repository

# %%
# !pip install dominate

# %%
# !git clone https://github.com/NVIDIA/pix2pixHD
# Out:
# Cloning into 'pix2pixHD'...
# remote: Enumerating objects: 340, done.
# remote: Total 340 (delta 0), reused 0 (delta 0), pack-reused 340
# Receiving objects: 100% (340/340), 55.68 MiB | 22.94 MiB/s, done.
# Resolving deltas: 100% (156/156), done.

# %%
import os
os.chdir("pix2pixHD")

# %% [markdown]
# ## Unzip loaded files

# %%
# !unzip train_A.zip
# Out:
# Archive:  train_A.zip
#    creating: train_A/
#   inflating: train_A/.DS_Store
# replace __MACOSX/train_A/._.DS_Store? [y]es, [n]o, [A]ll, [N]one, [r]ename: A
#   inflating: __MACOSX/train_A/._.DS_Store
#   inflating: train_A/8.jpg
#   inflating: __MACOSX/train_A/._8.jpg
#   inflating: train_A/9.jpg
#   inflating: __MACOSX/train_A/._9.jpg
#   inflating: train_A/14.jpg
#   inflating: __MACOSX/train_A/._14.jpg
#   inflating: train_A/28.jpg
#   inflating: __MACOSX/train_A/._28.jpg
#   inflating: train_A/15.jpg
#   inflating: __MACOSX/train_A/._15.jpg
#   inflating: train_A/17.jpg
#   inflating: __MACOSX/train_A/._17.jpg
#   inflating: train_A/16.jpg
#   inflating: __MACOSX/train_A/._16.jpg
#   inflating: train_A/12.jpg
#   inflating: __MACOSX/train_A/._12.jpg
#   inflating: train_A/13.jpg
#   inflating: __MACOSX/train_A/._13.jpg
#   inflating: train_A/11.jpg
#   inflating: __MACOSX/train_A/._11.jpg
#   inflating: train_A/10.jpg
#   inflating: __MACOSX/train_A/._10.jpg
# ...

# %%
# !unzip train_B.zip
# Out:
# Archive:  train_B.zip
#    creating: train_B/
#   inflating: train_B/8.png
# replace __MACOSX/train_B/._8.png? [y]es, [n]o, [A]ll, [N]one, [r]ename: A
#   inflating: __MACOSX/train_B/._8.png
#   inflating: train_B/9.png
#   inflating: __MACOSX/train_B/._9.png
#   inflating: train_B/14.png
#   inflating: __MACOSX/train_B/._14.png
#   inflating: train_B/28.png
#   inflating: __MACOSX/train_B/._28.png
#   inflating: train_B/15.png
#   inflating: __MACOSX/train_B/._15.png
#   inflating: train_B/17.png
#   inflating: __MACOSX/train_B/._17.png
#   inflating: train_B/16.png
#   inflating: __MACOSX/train_B/._16.png
#   inflating: train_B/12.png
#   inflating: __MACOSX/train_B/._12.png
#   inflating: train_B/13.png
#   inflating: __MACOSX/train_B/._13.png
#   inflating: train_B/11.png
#   inflating: __MACOSX/train_B/._11.png
#   inflating: train_B/10.png
#   inflating: __MACOSX/train_B/._10.png
#   inflating: train_B/21.png
#   inflating: __MACOSX/train_B/._21.png
# ...

# %%
# !python train.py --name vinci --label_nc 0 --no_instance --loadSize 1024 --dataroot ./training_set
# Out:
# ------------ Options -------------
# batchSize: 1
# beta1: 0.5
# checkpoints_dir: ./checkpoints
# continue_train: False
# data_type: 32
# dataroot: ./training_set
# debug: False
# display_freq: 100
# display_winsize: 512
# feat_num: 3
# fineSize: 512
# fp16: False
# gpu_ids: [0]
# input_nc: 3
# instance_feat: False
# isTrain: True
# label_feat: False
# label_nc: 0
# lambda_feat: 10.0
# loadSize: 1024
# load_features: False
# load_pretrain:
# local_rank: 0
# lr: 0.0002
# max_dataset_size: inf
# model: pix2pixHD
# nThreads: 2
# n_blocks_global: 9
# n_blocks_local: 3
# n_clusters: 10
# n_downsample_E: 4
# n_downsample_global: 4
# n_layers_D: 3
# n_local_enhancers: 1
# name: vinci
# ndf: 64
# nef: 16
# netG: global
# ngf: 64
# niter: 100
# niter_decay: 100
# niter_fix_global: 0
# no_flip: False
# no_ganFeat_loss: False
# no_html: False
# no_instance: True
# no_lsgan: False
# no_vgg_loss: False
# norm: instance
# num_D: 2
# output_nc: 3
# phase: train
# pool_size: 0
# print_freq: 100
# ...

# %%
# !python test.py --name vinci --label_nc 0 --no_instance --loadSize 1024 --dataroot ./test_set
# Out:
# ------------ Options -------------
# aspect_ratio: 1.0
# batchSize: 1
# checkpoints_dir: ./checkpoints
# cluster_path: features_clustered_010.npy
# data_type: 32
# dataroot: ./test_set
# display_winsize: 512
# engine: None
# export_onnx: None
# feat_num: 3
# fineSize: 512
# fp16: False
# gpu_ids: [0]
# how_many: 50
# input_nc: 3
# instance_feat: False
# isTrain: False
# label_feat: False
# label_nc: 0
# loadSize: 1024
# load_features: False
# local_rank: 0
# max_dataset_size: inf
# model: pix2pixHD
# nThreads: 2
# n_blocks_global: 9
# n_blocks_local: 3
# n_clusters: 10
# n_downsample_E: 4
# n_downsample_global: 4
# n_local_enhancers: 1
# name: vinci
# nef: 16
# netG: global
# ngf: 64
# niter_fix_global: 0
# no_flip: False
# no_instance: True
# norm: instance
# ntest: inf
# onnx: None
# output_nc: 3
# phase: test
# resize_or_crop: scale_width
# results_dir: ./results/
# serial_batches: False
# tf_log: False
# use_dropout: False
# use_encoded_image: False
# verbose: False
# ...

# %%
# !python test.py --name vinci --label_nc 0 --no_instance --loadSize 1024 --dataroot ./test_set
# Out:
# ------------ Options -------------
# aspect_ratio: 1.0
# batchSize: 1
# checkpoints_dir: ./checkpoints
# cluster_path: features_clustered_010.npy
# data_type: 32
# dataroot: ./test_set
# display_winsize: 512
# engine: None
# export_onnx: None
# feat_num: 3
# fineSize: 512
# fp16: False
# gpu_ids: [0]
# how_many: 50
# input_nc: 3
# instance_feat: False
# isTrain: False
# label_feat: False
# label_nc: 0
# loadSize: 1024
# load_features: False
# local_rank: 0
# max_dataset_size: inf
# model: pix2pixHD
# nThreads: 2
# n_blocks_global: 9
# n_blocks_local: 3
# n_clusters: 10
# n_downsample_E: 4
# n_downsample_global: 4
# n_local_enhancers: 1
# name: vinci
# nef: 16
# netG: global
# ngf: 64
# niter_fix_global: 0
# no_flip: False
# no_instance: True
# norm: instance
# ntest: inf
# onnx: None
# output_nc: 3
# phase: test
# resize_or_crop: scale_width
# results_dir: ./results/
# serial_batches: False
# tf_log: False
# use_dropout: False
# use_encoded_image: False
# verbose: False
# ...

# %%
# !zip -r results.zip results/vinci/test_latest/
# Out:
# updating: results/vinci/test_latest/ (stored 0%)
#   adding: results/vinci/test_latest/images/ (stored 0%)
#   adding: results/vinci/test_latest/images/18_input_label.jpg (deflated 6%)
#   adding: results/vinci/test_latest/images/13_synthesized_image.jpg (deflated 4%)
#   adding: results/vinci/test_latest/images/23_input_label.jpg (deflated 6%)
#   adding: results/vinci/test_latest/images/13_input_label.jpg (deflated 14%)
#   adding: results/vinci/test_latest/images/10_synthesized_image.jpg (deflated 1%)
#   adding: results/vinci/test_latest/images/12_input_label.jpg (deflated 17%)
#   adding: results/vinci/test_latest/images/4_input_label.jpg (deflated 8%)
#   adding: results/vinci/test_latest/images/21_input_label.jpg (deflated 2%)
#   adding: results/vinci/test_latest/images/19_synthesized_image.jpg (deflated 1%)
#   adding: results/vinci/test_latest/images/19_input_label.jpg (deflated 3%)
#   adding: results/vinci/test_latest/images/20_synthesized_image.jpg (deflated 3%)
# ...

# %%
# !unzip vinci_paintings.zip
# Out:
# Archive:  vinci_paintings.zip
#    creating: vinci_paintings/
#   inflating: vinci_paintings/.DS_Store
#    creating: __MACOSX/vinci_paintings/
#   inflating: __MACOSX/vinci_paintings/._.DS_Store
#   inflating: vinci_paintings/8.jpg
#   inflating: vinci_paintings/9.jpg
#   inflating: vinci_paintings/14.jpg
#   inflating: vinci_paintings/15.jpg
#   inflating: vinci_paintings/17.jpg
#   inflating: vinci_paintings/16.jpg
#   inflating: vinci_paintings/12.jpg
#   inflating: __MACOSX/vinci_paintings/._12.jpg
#   inflating: vinci_paintings/13.jpg
#   inflating: vinci_paintings/11.jpg
#   inflating: __MACOSX/vinci_paintings/._11.jpg
#   inflating: vinci_paintings/10.jpg
#   inflating: vinci_paintings/21.jpg
#   inflating: vinci_paintings/20.jpg
#   inflating: vinci_paintings/22.jpg
#   inflating: vinci_paintings/23.jpg
#   inflating: __MACOSX/vinci_paintings/._23.jpg
#   inflating: vinci_paintings/18.jpg
#   inflating: vinci_paintings/24.jpg
#   inflating: vinci_paintings/25.jpg
# ...
